# %% [markdown]
# **Required imports**

# %%
import json
import jmespath
from dotenv import load_dotenv
from groq import Groq

# %% [markdown]
# **Load the JSON File**
# Lod the JSON file which has survey data arranged in multi level nesting

# %%
# Load JSON data from file
with open("survey_data.json", "r") as f:
    data = json.load(f)

# %% [markdown]
# >Key nesting is used as part of query.
# >Filter done at innesr most level (records)

# %%
# Search for volunteers in Jordan with education "High School"
query = "Jordan.volunteers[?education=='High School']"
results = jmespath.search(query, data)

# Print the filtered records
for person in results:
    print(person)
# Out:
# {'name': 'John Daniel', 'age': 48, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 82978.57, 'city': 'Smithshire', 'avg_weekly_work_hours': 49.5, 'location_type': 'Urban'}
# {'name': 'Jennifer Thompson', 'age': 37, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 95683.59, 'city': 'West Douglasville', 'avg_weekly_work_hours': 39.4, 'location_type': 'Urban'}
# {'name': 'Christina Snow', 'age': 24, 'sex': 'Other', 'education': 'High School', 'annual_earning_usd': 38819.56, 'city': 'Andersonbury', 'avg_weekly_work_hours': 31.6, 'location_type': 'Rural'}
# {'name': 'Jeremy Turner', 'age': 64, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 30972.85, 'city': 'North Maria', 'avg_weekly_work_hours': 22.0, 'location_type': 'Urban'}
# {'name': 'Eric Martinez', 'age': 29, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 43343.48, 'city': 'Fisherfort', 'avg_weekly_work_hours': 58.4, 'location_type': 'Rural'}
# {'name': 'Stephanie Flynn', 'age': 37, 'sex': 'Other', 'education': 'High School', 'annual_earning_usd': 149781.88, 'city': 'Chandlerchester', 'avg_weekly_work_hours': 55.9, 'location_type': 'Urban'}
# {'name': 'Angela Campos', 'age': 62, 'sex': 'Other', 'education': 'High School', 'annual_earning_usd': 132167.69, 'city': 'Smithtown', 'avg_weekly_work_hours': 24.5, 'location_type': 'Urban'}
# {'name': 'Michelle Ball', 'age': 50, 'sex': 'Female', 'education': 'High School', 'annual_earning_usd': 146745.48, 'city': 'East Michelle', 'avg_weekly_work_hours': 24.6, 'location_type': 'Urban'}
# {'name': 'Kelsey Perkins', 'age': 52, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 42222.76, 'city': 'Richardsonhaven', 'avg_weekly_work_hours': 37.8, 'location_type': 'Urban'}
# {'name': 'Bruce Owens', 'age': 53, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 94761.01, 'city': 'Davisfurt', 'avg_weekly_work_hours': 27.5, 'location_type': 'Rural'}
# {'name': 'James Alexander', 'age': 27, 'sex': 'Female', 'education': 'High School', 'annual_earning_usd': 127245.28, 'city': 'Anthonybury', 'avg_weekly_work_hours': 47.4, 'location_type': 'Urban'}
# {'name': 'Austin Ellis', 'age': 38, 'sex': 'Male', 'education': 'High School', 'annual_earning_usd': 31437.71, 'city': 'West Carol', 'avg_weekly_work_hours': 37.8, 'location_type': 'Urban'}
# {'name': 'Kevin Arroyo', 'age': 27, 'sex': 'Other', 'education': 'High School', 'annual_earning_usd': 46001.01, 'city': 'Fisherbury', 'avg_weekly_work_hours': 28.5, 'location_type': 'Urban'}
# {'name': 'Elizabeth Moore', 'age': 58, 'sex': 'Other', 'education': 'High School', 'annual_earning_usd': 78753.68, 'city': 'Deanland', 'avg_weekly_work_hours': 33.7, 'location_type': 'Urban'}

# %% [markdown]
# >Loop through at a level, to retain value of that field

# %%
# Extract names of urban residents per country
urban_names_per_country = {}

# Loop through the outer dimension
for country, info in data.items():
    #query to get names of volunteers living in urban areas
    query = "volunteers[?location_type=='Urban'].name"
    names = jmespath.search(query, info)
    urban_names_per_country[country] = names

urban_names_per_country
# Out:
# {'Jordan': ['Samuel Larson',
#   'John Daniel',
#   'Jennifer Thompson',
#   'Kathleen Patton',
#   'Michelle Rivers',
#   'Sean Lane',
#   'Jeffrey Heath',
#   'Jeremy Turner',
#   'Deborah Martinez',
#   'Jared Martinez',
#   'Brandon Gonzalez',
#   'Susan Anderson',
#   'Ashley Morgan',
#   'Joshua Butler',
#   'Stacy Hunter',
#   'Brendan Miller',
#   'Ms. Sherri Reilly',
#   'Tracy Casey',
#   'Ashley Spencer',
#   'Jake Sanders',
#   'Brittany Chen',
#   'Christian Sampson',
#   'David Park',
#   'Daniel Johnson',
#   'Stephanie Flynn',
#   'Madison Moore',
#   'Jonathan Alvarez',
#   'Angela Campos',
#   'Susan Ritter',
#   'Kimberly Weber',
#   'Michelle Ball',
#   'Joshua Blanchard',
#   'Kim White',
#   'Kelsey Perkins',
#   'Nathaniel Leonard',
#   'Beth Carroll',
#   'James Alexander',
#   'Robin Stevens',
#   'Austin Ellis',
#   'Catherine Werner',
#   'Laura Jones',
#   'Kevin Arroyo',
#   'Holly Burns',
#   'Jeanne Mendoza',
#   'Patrick Palmer',
#   'Elizabeth Moore',
#   'Erin Mcknight',
#   'Raven Wheeler',
#   'Allen Hooper',
#   'Brian Holt',
#   'Christian Long',
#   'Melissa Chen'],
#  'Moldova': ['Traci Mccarthy',
#   'Tina Floyd',
#   'Eric Harmon',
#   'Kimberly Foley',
#   'Austin Thompson',
#   'Tabitha Powell',
#   'Ana Perez',
#   'Justin Solis',
#   'Lori Horton',
#   'Megan Jones DVM',
#   'Natalie Fisher',
#   'David Jones',
#   'Mrs. Jill Carlson',
#   'Eric Snyder',
#   'Matthew Salinas',
#   'Benjamin Martinez',
#   'James Phillips',
#   'Dennis Hall',
#   'Maria Rodriguez',
#   'Robert Lopez',
#   'Monica Huff',
#   'Daniel Cabrera',
#   'Nicole Hamilton',
#   'Mary Bates',
#   'Ricky Kennedy',
#   'Aaron Wallace',
#   'Michael Smith',
#   'Seth Salazar',
#   'Sarah Durham',
#   'William Davis',
#   'Jennifer Gallegos',
#   'Dawn Anderson',
#   'Kyle Mullen',
#   'Christopher Duncan',
#   'Dustin Armstrong',
#   'Aaron Little',
#   'Kevin Brewer',
#   'Amy Miranda',
#   'Scott Davila',
#   'Dustin Baker',
#   'Diane Mason',
#   'Christopher Hart',
#   'Tracy Miller',
#   'Timothy Gardner',
#   'Evan Levy',
#   'Isabel Jones',
#   'Melissa Ortega',
#   'Carla Brown'],
#  'Denmark': ['Kelly Martinez',
#   'Jesus Snyder',
#   'Justin Jimenez',
#   'Michael Harris',
#   'Mary Reyes',
#   'Joshua Green',
#   'Adam Pratt',
#   'Timothy Taylor',
#   'Katherine Green',
#   'Thomas Smith',
#   'Kristine Huffman',
#   'Brian Juarez',
#   'Gregory Hays',
#   'Barry Finley',
#   'Andrea Mccullough',
#   'David Keller',
#   'Melissa Tate',
#   'Michele Stone',
#   'Tom Baker',
#   'Amy Bowen',
#   'David Mosley',
#   'Jason Vasquez',
#   'Stacy Washington',
#   'Stacey Vargas',
#   'Valerie Knapp',
#   'Benjamin Baxter',
#   'Michael Alexander',
#   'Andrew Thompson',
#   'Ellen Sweeney',
#   'Amber Rice',
#   'Christopher Freeman',
#   'Jason Reid',
#   'Kiara Smith',
#   'Joshua Herrera',
#   'Nicole Suarez',
#   'Kelly Rice',
#   'Robert Olson',
#   'Cynthia Mckinney',
#   'Laura Duncan',
#   'Anthony Ross',
#   'Brittany Young',
#   'James Gibbs',
#   'Jose Grant',
#   'Meagan Price'],
#  'Gibraltar': ['Rodney Salazar',
#   'Miss Jodi Schneider',
#   'George Gray',
#   'Cynthia Bell',
#   'Megan Perez',
#   'Kenneth Brown',
#   'Tina Garrison',
#   'Amy Berry',
#   'Danielle Butler',
#   'Mary Small',
#   'Alec Harvey',
#   'Bruce Cochran',
#   'Jose Acevedo',
#   'Jacob Robertson',
#   'Jeffrey Burns',
#   'Lauren Reed',
#   'John Barker',
#   'Thomas Dean',
#   'Jesse Ortega',
#   'Mark Tucker',
#   'Kylie Robinson',
#   'Laura Hogan',
#   'Kayla Watson',
#   'Madison Weber',
#   'William Bishop',
#   'Dustin Benjamin',
#   'Curtis Mejia',
#   'Heather Bell',
#   'Anthony Gibbs',
#   'Rodney Hendricks',
#   'Alexis Taylor',
#   'Jason Rodriguez',
#   'Valerie Johnson',
#   'Pamela Escobar',
#   'Lacey Anderson',
#   'Brian Beck',
#   'Stephen Edwards',
#   'Michael Parker',
#   'Margaret Jenkins',
#   'Kenneth Roth',
#   'Theresa Stone',
#   'Nicole Valdez',
#   'James Peterson',
#   'James Hart',
#   'Katherine Torres',
#   'Linda Henry',
#   'Willie Stone',
#   'Taylor Thomas'],
#  'Morocco': ['Meghan Larson',
#   'James Hutchinson',
#   'Samuel Stevens',
#   'Thomas Wright',
#   'Mark Gibson',
#   'Nicole Carrillo',
#   'Thomas Fisher',
#   'Danielle Huffman',
#   'Robert Ashley',
#   'Michael Phelps',
#   'Donald Foster',
#   'Christopher Barrett',
#   'Joanna Sharp',
#   'Mary Wilson',
#   'Yvette Brown',
#   'Jamie West',
#   'Daniel Dodson',
#   'Debbie Perkins',
#   'Michele Chang',
#   'Mark Wallace',
#   'Monica Compton',
#   'Benjamin Kelly',
#   'Amy Jones',
#   'Samantha Torres',
#   'Jeremiah Jones',
#   'Margaret Abbott',
#   'Thomas Obrien',
#   'Sophia Jones',
#   'David Foster',
#   'Tina Higgins',
#   'Kristina Garcia',
#   'Karen Contreras',
#   'Sheila Rodriguez',
#   'Renee Wood',
#   'Susan Reyes',
#   'Julia Jones',
#   'Joel Sanchez',
#   'Erica Walls',
#   'Tammy Young',
#   'Elizabeth Simpson',
#   'Raymond Miller',
#   'Austin Frazier',
#   'Kelly Peters PhD',
#   'Dawn Cook',
#   'Sarah Simmons',
#   'Janet Garcia',
#   'Linda Stevens',
#   'Jessica Underwood']}

# %%
# Dictionary to hold results
phd_demographics_per_country = {}

# Apply JMESPath filter for each country
for country, info in data.items():
    result = jmespath.search("volunteers[?education=='PhD'][].{age: age, sex: sex}", info)
    if result:  # Only store countries with PhD individuals
        phd_demographics_per_country[country+' - PhD'] = result

phd_demographics_per_country
# Out:
# {'Jordan - PhD': [{'age': 28, 'sex': 'Female'},
#   {'age': 42, 'sex': 'Female'},
#   {'age': 45, 'sex': 'Male'},
#   {'age': 24, 'sex': 'Male'},
#   {'age': 27, 'sex': 'Other'},
#   {'age': 27, 'sex': 'Other'},
#   {'age': 51, 'sex': 'Female'},
#   {'age': 48, 'sex': 'Other'},
#   {'age': 61, 'sex': 'Female'},
#   {'age': 29, 'sex': 'Female'},
#   {'age': 58, 'sex': 'Male'},
#   {'age': 63, 'sex': 'Male'},
#   {'age': 45, 'sex': 'Other'},
#   {'age': 59, 'sex': 'Male'},
#   {'age': 37, 'sex': 'Female'},
#   {'age': 63, 'sex': 'Other'}],
#  'Moldova - PhD': [{'age': 25, 'sex': 'Other'},
#   {'age': 31, 'sex': 'Male'},
#   {'age': 42, 'sex': 'Other'},
#   {'age': 22, 'sex': 'Other'},
#   {'age': 54, 'sex': 'Male'},
#   {'age': 19, 'sex': 'Male'},
#   {'age': 38, 'sex': 'Male'},
#   {'age': 49, 'sex': 'Other'},
#   {'age': 67, 'sex': 'Female'},
#   {'age': 58, 'sex': 'Female'},
#   {'age': 39, 'sex': 'Male'},
#   {'age': 69, 'sex': 'Other'},
#   {'age': 60, 'sex': 'Male'},
#   {'age': 24, 'sex': 'Male'},
#   {'age': 23, 'sex': 'Other'},
#   {'age': 28, 'sex': 'Male'},
#   {'age': 50, 'sex': 'Other'},
#   {'age': 44, 'sex': 'Female'},
#   {'age': 47, 'sex': 'Female'}],
#  'Denmark - PhD': [{'age': 21, 'sex': 'Female'},
#   {'age': 61, 'sex': 'Female'},
#   {'age': 22, 'sex': 'Other'},
#   {'age': 42, 'sex': 'Female'},
#   {'age': 56, 'sex': 'Male'},
#   {'age': 51, 'sex': 'Other'},
#   {'age': 38, 'sex': 'Other'},
#   {'age': 40, 'sex': 'Other'},
#   {'age': 38, 'sex': 'Female'},
#   {'age': 57, 'sex': 'Other'},
#   {'age': 61, 'sex': 'Male'},
#   {'age': 55, 'sex': 'Male'},
#   {'age': 21, 'sex': 'Female'}],
#  'Gibraltar - PhD': [{'age': 29, 'sex': 'Female'},
#   {'age': 66, 'sex': 'Female'},
#   {'age': 26, 'sex': 'Other'},
#   {'age': 32, 'sex': 'Male'},
#   {'age': 52, 'sex': 'Female'},
#   {'age': 59, 'sex': 'Other'},
#   {'age': 38, 'sex': 'Other'},
#   {'age': 59, 'sex': 'Male'},
#   {'age': 64, 'sex': 'Female'},
#   {'age': 29, 'sex': 'Male'},
#   {'age': 35, 'sex': 'Male'},
#   {'age': 51, 'sex': 'Other'},
#   {'age': 41, 'sex': 'Other'},
#   {'age': 58, 'sex': 'Female'},
#   {'age': 49, 'sex': 'Other'},
#   {'age': 21, 'sex': 'Male'},
#   {'age': 69, 'sex': 'Male'},
#   {'age': 64, 'sex': 'Female'}],
#  'Morocco - PhD': [{'age': 23, 'sex': 'Female'},
#   {'age': 41, 'sex': 'Male'},
#   {'age': 32, 'sex': 'Male'},
#   {'age': 41, 'sex': 'Female'},
#   {'age': 53, 'sex': 'Female'},
#   {'age': 60, 'sex': 'Male'},
#   {'age': 18, 'sex': 'Male'},
#   {'age': 27, 'sex': 'Female'},
#   {'age': 18, 'sex': 'Male'},
#   {'age': 36, 'sex': 'Other'},
#   {'age': 53, 'sex': 'Male'},
#   {'age': 28, 'sex': 'Male'},
#   {'age': 20, 'sex': 'Female'}]}

# %% [markdown]
# **Retrived Data to LLM**
# The data retrieved from JSON is provided to LLM as context
# This provides the relevant data to respond to the prompt

# %%
load_dotenv()
client = Groq()

# %% [markdown]
# >Specific instuction for Response

# %%
R_Instr = "Using the context given, provide response to the user question or statement.\
            Context is provided in JSON format.\
            Provide a comprehensive response"

# %% [markdown]
# >The data is being retireved from JSON using list comprehension

# %%
# User prompt
Prompt = "Who is more educated, in each country? Ladies or Gents?"

# Filter out only relevant fields
filtered_data = {
    country: [
        {"sex": v["sex"], "education": v["education"]}
        for v in info["volunteers"]
    ]
    for country, info in data.items()
}

Context = json.dumps (filtered_data)

# Invoke LLM with prompt and context
messages=[
    {
        "role": "system",
        "content": R_Instr
    },

    {
        "role": "user",
        "content":"Context : \n"+ Context
    },

    {
        "role": "user",
        "content": "Query : \n" + Prompt
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="openai/gpt-oss-120b",
)

print (completion.choices[0].message.content)
# Out:
# **How we decided who is “more educated”**
#
# 1. **Education hierarchy** (from lowest to highest)
#    1. No schooling
#    2. High School
#    3. Associate Degree
#    4. Bachelor’s
#    5. Master’s
#    6. PhD
#
# 2. **Scoring** – each level was given a numeric score (0‑5) that follows the hierarchy above.
# 3. **Average score per gender** – for every country we added the scores of all *Male* records and divided by the number of male records; we did the same for *Female* records. (People recorded as **Other** were omitted from the gender‑comparison because the query asks specifically about “Ladies or Gents”.)
#
# 4. **Result** – the gender with the higher average score is considered the “more educated” group in that country.
#
# Below is a summary of the calculations (rounded to two decimal places).
#
# | Country   | # Males | Avg. Male Score | # Females | Avg. Female Score | Who is more educated? |
# |-----------|--------|----------------|----------|-------------------|-----------------------|
# | **Jordan** | 57 | **2.31** | 31 | **2.81** | **Ladies** |
# | **Moldova**| 58 | **2.24** | 42 | **2.71** | **Ladies** |
# | **Denmark**| 69 | **2.07** | 44 | **2.57** | **Ladies** |
# | **Gibraltar**| 30 | **2.10** | 46 | **2.65** | **Ladies** |
# | **Morocco**| 71 | **2.19** | 56 | **2.58** | **Ladies** |
#
# *(The scores are on the 0‑5 scale described above; a higher number means a higher overall level of education.)*
#
# ---
#
# ### What the numbers tell us
#
# | Country | Why ladies lead |
# |---------|-----------------|
# | **Jordan** | Female respondents include a relatively large cluster of PhDs (7 % of all Jordanian records) and many Masters, while a sizable proportion of males are still in the “No schooling” or “High School” categories. |
# | **Moldova** | Although males have a good share of PhDs, females are over‑represented in the Master’s and Bachelor’s brackets, pulling the female average above the male one. |
# | **Denmark** | The male sample contains many “No schooling” and “High School” entries, whereas females are concentrated in the Bachelor‑to‑PhD range. |
# | **Gibraltar** | Female entries are heavily weighted toward Associate‑Degree, Bachelor’s, Master’s and PhD levels; male entries contain a noticeable share of “No schooling” and “High School”. |
# | **Morocco** | Women are present in every upper‑level category (Bachelor’s, Master’s, PhD) more often than men, while a sizable share of males remains at “High School” or “No schooling”. |
#
# ---
#
# ### Bottom line
#
# **In every country supplied (Jordan, Moldova, Denmark, Gibraltar, and Morocco) the female respondents have a higher average education level than the male respondents.**
#
# If you need the raw counts, the exact average scores, or a deeper dive (e.g., separating “Other” gender, looking at median education, etc.), just let me know and I can produce those tables for you.

# %% [markdown]
# The following assignments are provided to the learner to assess their python understanding after the python base camp 1. Do attempt them without the help of Gen AI 🙂. Of course you may take help of sample programs, online references etc …!

# %% [markdown]
# Assignment 1:::
#
# The file ‘city_temperature.csv’ provides sample data for daily average temperature for 5 cities across 3 months. Make python program to read and process this data into numpy arrays for the following requirements:
#
# Function to identify the day when max temperature recorded for each city. Return as a dict (city - temp pair)
# Function to identify the monthly average temperature for each of the city. Return dict.
# Consider the timeline into 5 days of sliding window. Identify for each city : the number of 5 day stretch(s) where temperature stayed more than that of monthly average.

# %%
import pandas as pd
import numpy as np

# Read the CSV file
df = pd.read_csv('city_temperature.csv - 1')

# Display the first few rows to understand the data
print("Dataset shape:", df.shape)
print("\nFirst few rows:")
print(df.head())
print("\nData info:")
print(df.info())
# Out:
# Dataset shape: (92, 6)
#
# First few rows:
#          Date  London  Tokyo  Sydney  Cairo   Rio
# 0  01-06-2024    15.5   23.1    13.8   28.5  21.0
# 1  02-06-2024    16.1   23.5    14.0   28.8  21.2
# 2  03-06-2024    16.3   23.8    14.2   29.1  21.5
# 3  04-06-2024    15.9   24.0    13.9   29.5  21.3
# 4  05-06-2024    16.5   24.2    13.5   29.8  21.7
#
# Data info:
# <class 'pandas.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    92 non-null     str
#  1   London  92 non-null     float64
#  2   Tokyo   92 non-null     float64
#  3   Sydney  92 non-null     float64
#  4   Cairo   92 non-null     float64
#  5   Rio     92 non-null     float64
# dtypes: float64(5), str(1)
# memory usage: 4.4 KB
# None

# %%
# Convert data to numpy arrays for each city
cities = df.columns[1:]  # Skip the 'Date' column
city_arrays = {}

for city in cities:
    city_arrays[city] = df[city].values

print("Cities processed:", list(city_arrays.keys()))
print("\nArray shape for London:", city_arrays['London'].shape)
# Out:
# Cities processed: ['London', 'Tokyo', 'Sydney', 'Cairo', 'Rio']
#
# Array shape for London: (92,)

# %%
# Function 1: Identify the day when max temperature recorded for each city
def max_temperature_day(city_arrays, df):
    """
    Find the day (index) when maximum temperature was recorded for each city.
    
    Args:
        city_arrays: Dictionary with city names as keys and numpy arrays as values
        df: Original dataframe with Date column
    
    Returns:
        Dictionary with city as key and (day, max_temp) as value
    """
    max_temp_days = {}
    
    for city, temps in city_arrays.items():
        max_idx = np.argmax(temps)  # Get index of max temperature
        max_temp = temps[max_idx]
        date = df['Date'].iloc[max_idx]
        max_temp_days[city] = {'date': date, 'day_index': max_idx, 'max_temperature': max_temp}
    
    return max_temp_days

# Function 2: Identify the monthly average temperature for each city
def monthly_average_temperature(city_arrays, df):
    """
    Calculate the average temperature for each city across the entire period.
    
    Args:
        city_arrays: Dictionary with city names as keys and numpy arrays as values
    
    Returns:
        Dictionary with city as key and average temperature as value
    """
    monthly_avg = {}
    
    for city, temps in city_arrays.items():
        avg_temp = np.mean(temps)
        monthly_avg[city] = avg_temp
    
    return monthly_avg

# Function 3: Count 5-day stretches where temperature stayed above monthly average
def five_day_stretches_above_average(city_arrays, monthly_avg):
    """
    Identify stretches of 5 consecutive days where temperature exceeded the monthly average.
    
    Args:
        city_arrays: Dictionary with city names as keys and numpy arrays as values
        monthly_avg: Dictionary with city as key and monthly average temperature as value
    
    Returns:
        Dictionary with city as key and count of stretches above average as value
    """
    stretches_above_avg = {}
    window_size = 5
    
    for city, temps in city_arrays.items():
        avg_temp = monthly_avg[city]
        count = 0
        
        # Iterate through the array with a sliding window of size 5
        for i in range(len(temps) - window_size + 1):
            window = temps[i:i + window_size]
            # Check if all temperatures in the window are above the monthly average
            if np.all(window > avg_temp):
                count += 1
        
        stretches_above_avg[city] = count
    
    return stretches_above_avg

print("All functions defined successfully!")
# Out:
# All functions defined successfully!

# %%
# Execute the functions
max_temp_days = max_temperature_day(city_arrays, df)
monthly_avg_temps = monthly_average_temperature(city_arrays, df)
stretches_above_avg = five_day_stretches_above_average(city_arrays, monthly_avg_temps)

print("=" * 70)
print("ASSIGNMENT 1 RESULTS")
print("=" * 70)

print("\n1. MAXIMUM TEMPERATURE DAY FOR EACH CITY:")
print("-" * 70)
for city, info in max_temp_days.items():
    print(f"\n{city}:")
    print(f"  Date: {info['date']}")
    print(f"  Day Index: {info['day_index']}")
    print(f"  Max Temperature: {info['max_temperature']:.1f}°C")

print("\n\n2. MONTHLY AVERAGE TEMPERATURE FOR EACH CITY:")
print("-" * 70)
for city, avg_temp in monthly_avg_temps.items():
    print(f"{city}: {avg_temp:.2f}°C")

print("\n\n3. COUNT OF 5-DAY STRETCHES WITH TEMPERATURE ABOVE MONTHLY AVERAGE:")
print("-" * 70)
for city, count in stretches_above_avg.items():
    print(f"{city}: {count} stretches")
# Out:
# ======================================================================
# ASSIGNMENT 1 RESULTS
# ======================================================================
#
# 1. MAXIMUM TEMPERATURE DAY FOR EACH CITY:
# ----------------------------------------------------------------------
#
# London:
#   Date: 30-08-2024
#   Day Index: 90
#   Max Temperature: 21.7°C
#
# Tokyo:
#   Date: 30-08-2024
#   Day Index: 90
#   Max Temperature: 31.9°C
#
# Sydney:
#   Date: 28-08-2024
#   Day Index: 88
#   Max Temperature: 16.0°C
#
# Cairo:
#   Date: 30-08-2024
#   Day Index: 90
#   Max Temperature: 36.8°C
#
# Rio:
#   Date: 30-08-2024
#   Day Index: 90
#   Max Temperature: 27.4°C
#
#
# 2. MONTHLY AVERAGE TEMPERATURE FOR EACH CITY:
# ----------------------------------------------------------------------
# London: 19.23°C
# Tokyo: 28.26°C
# Sydney: 14.31°C
# Cairo: 33.37°C
# Rio: 24.31°C
#
#
# 3. COUNT OF 5-DAY STRETCHES WITH TEMPERATURE ABOVE MONTHLY AVERAGE:
# ----------------------------------------------------------------------
# London: 42 stretches
# Tokyo: 42 stretches
# Sydney: 19 stretches
# Cairo: 42 stretches
# Rio: 36 stretches

# %% [markdown]
# Assignment 2:::
#
# The file ‘student_scores.csv’ provides sample data of students and their test score along with attendance and project status. This is available in a CSV file. Use this content and create a python program (using pandas) for the following requirements. Make them as functions in a module.
#
# Function that reads the CSV file and returns subject wise topper(s) and overall topper(s), such that:
# Toppers shall have at least 60% attendance
# Toppers shall have the project submitted.
#
# A function that returns a data frame with the following columns added along with original data:
# ‘Average Score’ : For each student
# ‘Grade’ :  based on average score (A : >= 90; B : 75 .. 89.99; C : 60 .. 74.99; D : <60)
# ‘Performance’ :
# ‘Excellent’ : Grade A and attendance > 90%, project submitted
# ‘Needs Attention’ : Grade D OR project not submitted OR attendance < 60%
# ‘Satisfactory’ : All others
# A function that exports the summary statistics of the subject wise marks, attendance to a CSV file.

# %%
# Load and explore the student_scores data
df_students = pd.read_csv('student_scores.csv - 1')

print("Dataset shape:", df_students.shape)
print("\nFirst few rows:")
print(df_students.head())
print("\nColumn names:")
print(df_students.columns.tolist())
print("\nData info:")
print(df_students.info())
# Out:
# Dataset shape: (200, 6)
#
# First few rows:
#              Name  Math  Science  English  Attendance (%)  Project Submitted
# 0    Robert Roman    78       93       96           96.55               True
# 1  Joseph Sanchez    91       62       60           98.71               True
# 2  Christina Hall    68       76       57           99.80              False
# 3       Ann Brown    54       79       94           52.79               True
# 4  Thomas Herrera    82       96       86           86.85               True
#
# Column names:
# ['Name', 'Math', 'Science', 'English', 'Attendance (%)', 'Project Submitted']
#
# Data info:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               200 non-null    str
#  1   Math               200 non-null    int64
#  2   Science            200 non-null    int64
#  3   English            200 non-null    int64
#  4   Attendance (%)     200 non-null    float64
#  5   Project Submitted  200 non-null    bool
# dtypes: bool(1), float64(1), int64(3), str(1)
# memory usage: 8.1 KB
# None

# %%
# Function 1: Get subject-wise and overall toppers with conditions
def get_toppers(df):
    """
    Find subject-wise and overall toppers with conditions:
    - At least 60% attendance
    - Project submitted
    
    Args:
        df: DataFrame with student data
    
    Returns:
        Dictionary with 'subject_toppers' and 'overall_toppers'
    """
    # Filter students based on conditions
    filtered_df = df[(df['Attendance (%)'] >= 60) & (df['Project Submitted'] == True)].copy()
    
    if filtered_df.empty:
        return {'subject_toppers': {}, 'overall_toppers': {'toppers': [], 'average_score': 0}}
    
    # Subject-wise toppers
    subjects = ['Math', 'Science', 'English']
    subject_toppers = {}
    
    for subject in subjects:
        max_score = filtered_df[subject].max()
        toppers = filtered_df[filtered_df[subject] == max_score]['Name'].tolist()
        subject_toppers[subject] = {
            'toppers': toppers,
            'score': max_score
        }
    
    # Overall topper(s) - based on average score
    filtered_df['Average_Score'] = filtered_df[subjects].mean(axis=1)
    max_avg = filtered_df['Average_Score'].max()
    overall_toppers = filtered_df[filtered_df['Average_Score'] == max_avg]['Name'].tolist()
    
    result = {
        'subject_toppers': subject_toppers,
        'overall_toppers': {
            'toppers': overall_toppers,
            'average_score': max_avg
        }
    }
    
    return result

# Function 2: Add Average Score, Grade, and Performance columns
def add_student_analysis(df):
    """
    Add columns for Average Score, Grade, and Performance to the dataframe.
    
    Args:
        df: DataFrame with student data
    
    Returns:
        DataFrame with new columns added
    """
    df_analysis = df.copy()
    subjects = ['Math', 'Science', 'English']
    
    # Calculate Average Score
    df_analysis['Average Score'] = df_analysis[subjects].mean(axis=1)
    
    # Assign Grade
    def assign_grade(avg_score):
        if avg_score >= 90:
            return 'A'
        elif avg_score >= 75:
            return 'B'
        elif avg_score >= 60:
            return 'C'
        else:
            return 'D'
    
    df_analysis['Grade'] = df_analysis['Average Score'].apply(assign_grade)
    
    # Assign Performance
    def assign_performance(row):
        grade = row['Grade']
        attendance = row['Attendance (%)']
        project = row['Project Submitted']
        
        # Excellent: Grade A and attendance > 90%, project submitted
        if grade == 'A' and attendance > 90 and project == True:
            return 'Excellent'
        
        # Needs Attention: Grade D OR project not submitted OR attendance < 60%
        if grade == 'D' or project == False or attendance < 60:
            return 'Needs Attention'
        
        # Satisfactory: All others
        return 'Satisfactory'
    
    df_analysis['Performance'] = df_analysis.apply(assign_performance, axis=1)
    
    return df_analysis

# Function 3: Export summary statistics
def export_summary_statistics(df, filename='summary_statistics.csv'):
    """
    Export subject-wise and overall summary statistics to CSV.
    
    Args:
        df: DataFrame with student data
        filename: Output filename
    
    Returns:
        Summary statistics dataframe
    """
    subjects = ['Math', 'Science', 'English']
    summary_data = []
    
    # Subject-wise statistics
    for subject in subjects:
        summary_data.append({
            'Subject': subject,
            'Mean': df[subject].mean(),
            'Median': df[subject].median(),
            'Std Dev': df[subject].std(),
            'Min': df[subject].min(),
            'Max': df[subject].max()
        })
    
    # Attendance statistics
    summary_data.append({
        'Subject': 'Attendance (%)',
        'Mean': df['Attendance (%)'].mean(),
        'Median': df['Attendance (%)'].median(),
        'Std Dev': df['Attendance (%)'].std(),
        'Min': df['Attendance (%)'].min(),
        'Max': df['Attendance (%)'].max()
    })
    
    summary_df = pd.DataFrame(summary_data)
    summary_df.to_csv(filename, index=False)
    
    return summary_df

print("All functions defined successfully!")
# Out:
# All functions defined successfully!

# %%
# Execute all Assignment 2 functions
print("=" * 80)
print("ASSIGNMENT 2 RESULTS")
print("=" * 80)

# Function 1: Get toppers
print("\n1. SUBJECT-WISE AND OVERALL TOPPERS (with conditions):")
print("-" * 80)
toppers_result = get_toppers(df_students)

print("\nSubject-Wise Toppers:")
for subject, info in toppers_result['subject_toppers'].items():
    print(f"  {subject}: {', '.join(info['toppers'])} (Score: {info['score']})")

print("\nOverall Topper(s):")
print(f"  {', '.join(toppers_result['overall_toppers']['toppers'])} (Average Score: {toppers_result['overall_toppers']['average_score']:.2f})")

# Function 2: Add analysis columns
print("\n\n2. STUDENT ANALYSIS WITH GRADES AND PERFORMANCE:")
print("-" * 80)
df_with_analysis = add_student_analysis(df_students)

# Display relevant columns
display_cols = ['Name', 'Math', 'Science', 'English', 'Average Score', 'Grade', 'Attendance (%)', 'Performance']
print("\nSample of processed data:")
print(df_with_analysis[display_cols].head(10).to_string(index=False))

print("\n\nPerformance Summary:")
performance_counts = df_with_analysis['Performance'].value_counts()
for perf, count in performance_counts.items():
    print(f"  {perf}: {count} students")

print("\n\nGrade Distribution:")
grade_counts = df_with_analysis['Grade'].value_counts().sort_index(ascending=False)
for grade, count in grade_counts.items():
    print(f"  Grade {grade}: {count} students")

# Function 3: Export summary statistics
print("\n\n3. SUMMARY STATISTICS (exported to CSV):")
print("-" * 80)
summary_stats = export_summary_statistics(df_with_analysis)
print(summary_stats.to_string(index=False))
print(f"\nFile saved as: summary_statistics.csv")
# Out:
# ================================================================================
# ASSIGNMENT 2 RESULTS
# ================================================================================
#
# 1. SUBJECT-WISE AND OVERALL TOPPERS (with conditions):
# --------------------------------------------------------------------------------
#
# Subject-Wise Toppers:
#   Math: Rachel Mcneil, Ashley Garcia, Heidi Edwards (Score: 99)
#   Science: Benjamin Stein (Score: 98)
#   English: Warren Harris (Score: 99)
#
# Overall Topper(s):
#   Ashley Garcia (Average Score: 93.67)
#
#
# 2. STUDENT ANALYSIS WITH GRADES AND PERFORMANCE:
# --------------------------------------------------------------------------------
#
# Sample of processed data:
#            Name  Math  Science  English  Average Score Grade  Attendance (%)     Performance
#    Robert Roman    78       93       96      89.000000     B           96.55    Satisfactory
#  Joseph Sanchez    91       62       60      71.000000     C           98.71    Satisfactory
#  Christina Hall    68       76       57      67.000000     C           99.80 Needs Attention
#       Ann Brown    54       79       94      75.666667     B           52.79 Needs Attention
#  Thomas Herrera    82       96       86      88.000000     B           86.85    Satisfactory
#  Zachary Walker    47       91       74      70.666667     C           77.30    Satisfactory
# Melinda Ramirez    60       40       63      54.333333     D           85.29 Needs Attention
#      Edgar Cole    78       62       61      67.000000     C           98.43    Satisfactory
#    Angela Moore    97       62       63      74.000000     C           84.40 Needs Attention
#     Amy Diaz MD    58       78       72      69.333333     C           91.85    Satisfactory
#
#
# Performance Summary:
#   Needs Attention: 114 students
#   Satisfactory: 86 students
#
#
# Grade Distribution:
#   Grade D: 29 students
#   Grade C: 106 students
#   Grade B: 61 students
#   Grade A: 4 students
#
#
# 3. SUMMARY STATISTICS (exported to CSV):
# --------------------------------------------------------------------------------
#        Subject     Mean  Median   Std Dev   Min  Max
#           Math 69.32500  68.500 17.390270 40.00 99.0
#        Science 68.16500  67.000 19.005362 35.00 99.0
#        English 72.87000  73.000 15.464763 45.00 99.0
# Attendance (%) 75.36725  75.625 14.149397 50.13 99.8
#
# File saved as: summary_statistics.csv

# %%
# Display the complete processed dataframe
print("\n" + "=" * 80)
print("COMPLETE STUDENT ANALYSIS DATAFRAME")
print("=" * 80)
print(f"\nTotal Students: {len(df_with_analysis)}\n")

# Show all columns for reference
print("Full dataframe (all columns):")
print(df_with_analysis.to_string(index=False))
# Out:
# ================================================================================
# COMPLETE STUDENT ANALYSIS DATAFRAME
# ================================================================================
#
# Total Students: 200
#
# Full dataframe (all columns):
#                Name  Math  Science  English  Attendance (%)  Project Submitted  Average Score Grade     Performance
#        Robert Roman    78       93       96           96.55               True      89.000000     B    Satisfactory
#      Joseph Sanchez    91       62       60           98.71               True      71.000000     C    Satisfactory
#      Christina Hall    68       76       57           99.80              False      67.000000     C Needs Attention
#           Ann Brown    54       79       94           52.79               True      75.666667     B Needs Attention
#      Thomas Herrera    82       96       86           86.85               True      88.000000     B    Satisfactory
#      Zachary Walker    47       91       74           77.30               True      70.666667     C    Satisfactory
#     Melinda Ramirez    60       40       63           85.29               True      54.333333     D Needs Attention
#          Edgar Cole    78       62       61           98.43               True      67.000000     C    Satisfactory
#        Angela Moore    97       62       63           84.40              False      74.000000     C Needs Attention
#         Amy Diaz MD    58       78       72           91.85               True      69.333333     C    Satisfactory
#       Warren Harris    62       64       99           93.34               True      75.000000     B    Satisfactory
#        Joshua Garza    50       96       70           91.92               True      72.000000     C    Satisfactory
#   Stephanie Freeman    50       96       81           71.30               True      75.666667     B    Satisfactory
#       Bryce Mendoza    63       35       70           61.13               True      56.000000     D Needs Attention
#      Danielle Stout    92       61       97           69.83               True      83.333333     B    Satisfactory
#       Michele Brown    75       96       67           94.59               True      79.333333     B    Satisfactory
#       Donna Elliott    79       37       53           57.33              False      56.333333     D Needs Attention
#         Jean Savage    63       61       56           75.67               True      60.000000     C    Satisfactory
#  Steven Johnson Jr.    42       43       97           61.66              False      60.666667     C Needs Attention
#   Douglas Hernandez    61       96       45           79.07              False      67.333333     C Needs Attention
#     Adrienne Howell    92       71       45           93.16               True      69.333333     C    Satisfactory
#          James West    41       85       91           94.02               True      72.333333     C    Satisfactory
#    Elizabeth Fowler    63       78       78           61.83              False      73.000000     C Needs Attention
#          Joseph Lam    83       58       76           95.38              False      72.333333     C Needs Attention
#    Michelle Kaufman    69       93       98           79.59              False      86.666667     B Needs Attention
#     Deborah Herrera    77       66       92           67.51               True      78.333333     B    Satisfactory
#        Amanda Zhang    41       86       69           85.41               True      65.333333     C    Satisfactory
#         Daniel Haas    99       96       84           74.08              False      93.000000     A Needs Attention
#          Becky Knox    60       92       89           68.90               True      80.333333     B    Satisfactory
#    Christopher King    72       86       97           85.25               True      85.000000     B    Satisfactory
#        Kim Cantrell    51       46       45           62.44              False      47.333333     D Needs Attention
#        Juan Jenkins    97       73       60           66.51               True      76.666667     B    Satisfactory
#        Andre Pruitt    61       36       83           71.72              False      60.000000     C Needs Attention
#   Christopher Grant    83       37       49           62.68              False      56.333333     D Needs Attention
#        Matthew Gray    64       90       66           70.26              False      73.333333     C Needs Attention
#     Pam Cabrera DDS    88       93       73           78.57               True      84.666667     B    Satisfactory
#         Laura Clark    66       36       99           87.05              False      67.000000     C Needs Attention
#         Andre Moran    98       36       47           88.36               True      60.333333     C    Satisfactory
#         Brenda Page    81       88       56           91.14              False      75.000000     B Needs Attention
#          Briana Fox    67       35       70           87.21               True      57.333333     D Needs Attention
#        Jean Spencer    99       53       60           84.05              False      70.666667     C Needs Attention
#      Alejandro Hall    55       36       95           61.88              False      62.000000     C Needs Attention
#       Carlos Reeves    54       87       81           70.01               True      74.000000     C    Satisfactory
#       Charles Morse    86       78       66           73.89               True      76.666667     B    Satisfactory
#      Patrick Hansen    90       66       73           54.14               True      76.333333     B Needs Attention
#   Christina Simmons    83       66       58           76.42               True      69.000000     C    Satisfactory
# Cheyenne Villanueva    94       89       72           71.82              False      85.000000     B Needs Attention
#    Kenneth Carrillo    91       90       49           90.11               True      76.666667     B    Satisfactory
#         Juan Murphy    96       51       91           98.90               True      79.333333     B    Satisfactory
#      Michael Wright    42       72       93           77.80               True      69.000000     C    Satisfactory
#   Laurie Murray DDS    76       58       74           66.13              False      69.333333     C Needs Attention
#        Rebecca York    90       45       90           52.17              False      75.000000     B Needs Attention
#       Jessica Gross    46       50       96           96.23              False      64.000000     C Needs Attention
#       Bobby Collins    60       93       49           95.96              False      67.333333     C Needs Attention
#      John Hernandez    48       37       56           62.65               True      47.000000     D Needs Attention
#       Zachary Pratt    78       54       60           84.77              False      64.000000     C Needs Attention
#       Annette Allen    57       93       70           53.77              False      73.333333     C Needs Attention
#           Gary Long    43       70       70           58.31               True      61.000000     C Needs Attention
#       Jonathan Reid    64       53       92           60.84              False      69.666667     C Needs Attention
#       Rachel Mcneil    99       53       65           64.72               True      72.333333     C    Satisfactory
#          Brian Leon    53       54       83           99.79               True      63.333333     C    Satisfactory
#       Melissa Novak    89       86       80           84.85               True      85.000000     B    Satisfactory
#      Jennifer Kline    97       67       77           69.21               True      80.333333     B    Satisfactory
#   Jennifer Martinez    48       74       74           86.86              False      65.333333     C Needs Attention
#      Melissa Flores    65       73       81           95.76              False      73.000000     C Needs Attention
#     Natasha Alvarez    92       35       67           97.94              False      64.666667     C Needs Attention
#     Douglas Daniels    41       45       54           52.89               True      46.666667     D Needs Attention
#   Mr. George Deleon    59       91       98           69.73              False      82.666667     B Needs Attention
#      Jessica Miller    67       84       49           55.34               True      66.666667     C Needs Attention
#      Matthew Wilson    86       57       80           66.78               True      74.333333     C    Satisfactory
#          Terry Cook    99       65       78           58.48               True      80.666667     B Needs Attention
#      Gregory Martin    46       76       96           82.34              False      72.666667     C Needs Attention
# Angela Williams PhD    83       41       75           69.41              False      66.333333     C Needs Attention
#        Jenny Warren    47       50       54           61.47              False      50.333333     D Needs Attention
#      Megan Harrison    86       94       63           63.30               True      81.000000     B    Satisfactory
#       Seth Mcdowell    74       36       76           68.02               True      62.000000     C    Satisfactory
#       Rachel Weaver    53       35       45           63.00              False      44.333333     D Needs Attention
#    Tammy Bryant DVM    56       82       49           72.66               True      62.333333     C    Satisfactory
#        Bryan Savage    75       46       89           51.62              False      70.000000     C Needs Attention
#    Daniel Robertson    89       71       48           63.99              False      69.333333     C Needs Attention
#     Kimberly Glover    79       66       60           70.56              False      68.333333     C Needs Attention
#         Evan Mcneil    43       43       68           80.14               True      51.333333     D Needs Attention
#        Daniel Davis    41       53       60           63.55              False      51.333333     D Needs Attention
#       Crystal Baker    45       82       99           56.66               True      75.333333     B Needs Attention
#         Ian Edwards    93       37       46           53.81               True      58.666667     D Needs Attention
#      Jason Thompson    81       54       93           97.03              False      76.000000     B Needs Attention
#      Heather Dorsey    43       58       72           70.83              False      57.666667     D Needs Attention
#        Mark Baldwin    93       88       76           79.06              False      85.666667     B Needs Attention
#          Erin Wolfe    68       67       71           95.96              False      68.666667     C Needs Attention
#          Rhonda Lee    57       58       64           54.14               True      59.666667     D Needs Attention
#         David Klein    65       70       68           93.83               True      67.666667     C    Satisfactory
#           Todd Soto    83       72       56           77.58              False      70.333333     C Needs Attention
#     Andrew Schwartz    73       59       94           58.24               True      75.333333     B Needs Attention
#          Maria Bird    49       52       79           70.56               True      60.000000     C    Satisfactory
#        Cody Padilla    75       88       77           88.88               True      80.000000     B    Satisfactory
#     Stephen Shaffer    53       69       77           74.02               True      66.333333     C    Satisfactory
#       Pamela Cooper    70       95       95           99.26               True      86.666667     B    Satisfactory
#        Amy Thompson    87       75       87           68.84              False      83.000000     B Needs Attention
#          Kevin Chen    54       67       81           87.48               True      67.333333     C    Satisfactory
#   Sandra Mccullough    47       67       56           69.65              False      56.666667     D Needs Attention
#    Matthew Martinez    53       48       47           91.46              False      49.333333     D Needs Attention
#          Maria Boyd    62       55       45           78.45              False      54.000000     D Needs Attention
#         Joshua Reed    99       82       77           53.18              False      86.000000     B Needs Attention
#         Sean Garner    96       54       84           51.84               True      78.000000     B Needs Attention
#         Donna Payne    79       42       54           56.69               True      58.333333     D Needs Attention
#           Carol Lee    60       41       87           50.68              False      62.666667     C Needs Attention
#      Caitlyn Martin    55       51       88           53.77              False      64.666667     C Needs Attention
#       Kayla Burgess    84       67       73           84.59               True      74.666667     C    Satisfactory
#      Laura Williams    57       82       57           76.72              False      65.333333     C Needs Attention
#      Gregory Harris    86       93       56           87.50              False      78.333333     B Needs Attention
#   Kathleen Castillo    92       56       75           95.66               True      74.333333     C    Satisfactory
#    Barbara Thompson    63       64       90           79.26              False      72.333333     C Needs Attention
#    Jennifer Hawkins    65       72       46           86.31               True      61.000000     C    Satisfactory
#           Laura Ray    64       85       95           87.85              False      81.333333     B Needs Attention
#       Ashley Garcia    99       88       94           68.89               True      93.666667     A    Satisfactory
#       Heidi Edwards    99       42       79           62.05               True      73.333333     C    Satisfactory
#         Joseph Huff    99       61       67           60.25              False      75.666667     B Needs Attention
#       Edward Bryant    84       61       61           62.57               True      68.666667     C    Satisfactory
#         William Fox    80       55       70           63.74               True      68.333333     C    Satisfactory
#            Lee Moss    68       64       52           60.36              False      61.333333     C Needs Attention
#     Alison Williams    54       62       73           93.91               True      63.000000     C    Satisfactory
#      Benjamin Stein    84       98       70           87.85               True      84.000000     B    Satisfactory
#        Kayla Thomas    40       95       54           52.34              False      63.000000     C Needs Attention
#       Randy Mathews    64       82       70           63.43              False      72.000000     C Needs Attention
#      Eddie Martinez    46       53       78           51.11               True      59.000000     D Needs Attention
#       Anthony Walls    48       38       95           74.91               True      60.333333     C    Satisfactory
#          Emily Pena    63       69       85           73.81              False      72.333333     C Needs Attention
#         Sylvia Lutz    40       98       51           91.57              False      63.000000     C Needs Attention
#         Nancy Davis    83       83       48           65.39               True      71.333333     C    Satisfactory
#        Jeffery Buck    47       51       97           90.82               True      65.000000     C    Satisfactory
#         Sarah Mason    63       78       94           98.40               True      78.333333     B    Satisfactory
#          Emily Hill    50       64       89           54.42               True      67.666667     C Needs Attention
#       Denise Pierce    90       80       55           89.59               True      75.000000     B    Satisfactory
#         David Smith    56       40       73           79.50              False      56.333333     D Needs Attention
#         Robert Byrd    47       71       80           74.00               True      66.000000     C    Satisfactory
#        Megan Cortez    74       58       69           71.03               True      67.000000     C    Satisfactory
# Jennifer Hutchinson    74       80       65           89.23               True      73.000000     C    Satisfactory
#      Melanie Dillon    72       87       80           81.97              False      79.666667     B Needs Attention
#         Lisa Grimes    98       94       54           90.25               True      82.000000     B    Satisfactory
#       Jordan Flores    44       97       81           95.16              False      74.000000     C Needs Attention
#        Angela Myers    81       66       53           80.86              False      66.666667     C Needs Attention
#       Sherry Steele    78       67       68           99.02               True      71.000000     C    Satisfactory
#       Jean Williams    97       52       79           80.40               True      76.000000     B    Satisfactory
#      Andrea Collins    80       59       93           81.83              False      77.333333     B Needs Attention
#       Wayne Simpson    67       88       79           77.74              False      78.000000     B Needs Attention
#        Jill Jackson    46       92       92           54.55              False      76.666667     B Needs Attention
#      Samantha Smith    48       80       80           86.32              False      69.333333     C Needs Attention
#    Stephanie Miller    47       58       62           77.37              False      55.666667     D Needs Attention
#    Joseph Rodriguez    51       66       93           72.55               True      70.000000     C    Satisfactory
#       Jason Krueger    73       81       83           95.52               True      79.000000     B    Satisfactory
#      Darrell Martin    72       57       76           64.90               True      68.333333     C    Satisfactory
#     Jessica Johnson    87       61       68           76.18               True      72.000000     C    Satisfactory
#       Bethany Green    94       36       67           84.88              False      65.666667     C Needs Attention
#      Justin Sellers    62       51       76           89.82               True      63.000000     C    Satisfactory
#        Andrew Keith    63       67       81           72.97               True      70.333333     C    Satisfactory
#       Richard Moore    76       43       56           92.10               True      58.333333     D Needs Attention
#       Mark Thompson    74       77       93           88.45               True      81.333333     B    Satisfactory
#         Whitney Kim    83       82       99           53.31               True      88.000000     B Needs Attention
#           John Wade    79       73       57           52.29               True      69.666667     C Needs Attention
#       Tammy Holland    61       76       67           81.04               True      68.000000     C    Satisfactory
#        Wesley Blair    66       60       69           67.37               True      65.000000     C    Satisfactory
#         Amy Brennan    74       84       79           60.46               True      79.000000     B    Satisfactory
#     Allison Freeman    40       59       85           78.98              False      61.333333     C Needs Attention
#      Susan Thompson    74       58       74           67.08               True      68.666667     C    Satisfactory
#     Kathryn Trevino    76       47       61           76.86               True      61.333333     C    Satisfactory
#           Kyle Pham    86       94       93           73.01              False      91.000000     A Needs Attention
#          Ross Green    53       41       64           79.24              False      52.666667     D Needs Attention
#        Ronald Boyer    42       91       92           70.02               True      75.000000     B    Satisfactory
#         Logan Cohen    40       70       69           84.88               True      59.666667     D Needs Attention
#      Lauren Allison    44       79       66           59.00              False      63.000000     C Needs Attention
#      James Lang PhD    65       54       57           84.83               True      58.666667     D Needs Attention
#   Christopher Brown    94       99       63           70.58              False      85.333333     B Needs Attention
# Miss Brittany Jones    53       42       93           93.72              False      62.666667     C Needs Attention
#     Jennifer Bailey    78       50       80           75.76               True      69.333333     C    Satisfactory
#        Shawn Larson    66       48       56           98.66               True      56.666667     D Needs Attention
#      Michael Hunter    48       49       85           80.10               True      60.666667     C    Satisfactory
#         Kelli Greer    54       66       63           61.19              False      61.000000     C Needs Attention
#        Emma Douglas    54       97       56           91.09              False      69.000000     C Needs Attention
#  Nathaniel Anderson    65       85       53           67.25              False      67.666667     C Needs Attention
#      Susan Williams    81       59       51           67.38              False      63.666667     C Needs Attention
#     Pamela Petersen    99       92       72           51.59              False      87.666667     B Needs Attention
#       Emily Shields    52       97       58           77.44               True      69.000000     C    Satisfactory
#            Jo Brown    90       96       75           76.72               True      87.000000     B    Satisfactory
#       Terry Schmidt    71       56       96           67.80               True      74.333333     C    Satisfactory
#        Joshua Brown    78       92       63           94.71              False      77.666667     B Needs Attention
#        Omar Ruiz MD    88       92       91           56.44              False      90.333333     A Needs Attention
#          Tina Brown    91       83       60           66.50               True      78.000000     B    Satisfactory
#          Alice Dunn    71       86       97           66.08               True      84.666667     B    Satisfactory
#      Jennifer Pitts    43       76       49           54.61               True      56.000000     D Needs Attention
#  Christopher Mosley    69       49       79           74.06               True      65.666667     C    Satisfactory
#        Ashley Evans    76       88       56           84.39              False      73.333333     C Needs Attention
#       Jonathan Nash    62       94       69           75.58               True      75.000000     B    Satisfactory
#       Kenneth Mejia    78       42       96           57.85              False      72.000000     C Needs Attention
#     Gabrielle Clark    84       87       65           68.86               True      78.666667     B    Satisfactory
#       Joseph Rivera    54       94       80           50.13              False      76.000000     B Needs Attention
#        Brian Jacobs    82       39       97           93.42              False      72.666667     C Needs Attention
#       Jacob Walters    68       40       67           54.23               True      58.333333     D Needs Attention
#          Eric Curry    75       81       60           79.86               True      72.000000     C    Satisfactory
#     Sara Valdez DDS    52       89       83           99.31              False      74.666667     C Needs Attention
#      Jessica Barnes    71       74       89           76.83               True      78.000000     B    Satisfactory

# %%
print("\nEnd of Assignment 2 Results")
# Out:
# End of Assignment 2 Results

# %%
from groq import Groq
from dotenv import load_dotenv
load_dotenv()
client = Groq()
prompt = """Indian Independence Day is celebrated on August 15th."""  

messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    stop=None,
    temperature=1.0,
)

print (completion.choices[0].message.content)
# Out:
# That's correct. Indian Independence Day is indeed celebrated on August 15th. It commemorates the country's independence from British colonial rule, which was achieved on August 15, 1947. The day is marked with great enthusiasm and patriotism across India, with flag-hoisting ceremonies, parades, and other cultural events. It's a significant national holiday in India, honoring the nation's struggle for freedom and its emergence as a sovereign nation.

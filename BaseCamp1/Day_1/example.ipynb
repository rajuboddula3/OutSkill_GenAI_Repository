# %%
from groq import Groq
from dotenv import load_dotenv
load_dotenv()
client = Groq()
prompt = """Indian Independence Day is celebrated on August 15th."""  

messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    stop=None,
    temperature=1.0,
)

print (completion.choices[0].message.content)
# Out:
# That's correct. Indian Independence Day is indeed celebrated on August 15th every year. It commemorates the day when India gained independence from British colonial rule in 1947. The country was officially declared independent at midnight on August 15, 1947, with Jawaharlal Nehru hoisting the Indian national flag above the Red Fort in Delhi. Since then, August 15th has been celebrated as a national holiday in India, marking the country's freedom and sovereignty.

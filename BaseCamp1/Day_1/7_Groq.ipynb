# %% [markdown]
# ### Groq Usage for LLM ###
# **Library Need**
# To use the APIs provided by the groq platform, the library 'groq' is required.
# Ensure to have performed 'pip install groq'
# The API key from your Groq account would be required to execute this code

# %%
# Import required class from Groq
from groq import Groq
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
Client = Groq ()

# Client = Groq (api_key='Your API Key')

# %% [markdown]
# **Invoke for chat Completion**
# >The APIs can be used for invoking LLM models available in Groq for chat completion
# >Try with differet models and different prompt messages

# %%
prompt = "Tell me what is special about 12-Apr"

# Prompt needs to be organised as message (list of dict)
messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = Client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    # model="llama-3.3-70b-specdec",
    stop=None,
    temperature=1.0
)

print (completion.choices[0].message.content)
# Out:
# 12-Apr, or April 12, is a significant day for several reasons:
#
# 1. **Cosmonautics Day**: April 12 is celebrated as Cosmonautics Day in Russia and some other countries to commemorate the first human spaceflight by Yuri Gagarin on April 12, 1961. Gagarin orbited the Earth once, marking a historic milestone in space exploration.
# 2. **International Day of Human Space Flight**: The United Nations also recognizes April 12 as the International Day of Human Space Flight to promote international cooperation in space exploration and development.
# 3. ** Yuri's Night**: This day is also celebrated as Yuri's Night, a global event to commemorate Gagarin's achievement and promote interest in space exploration.
#
# These events make April 12 a special day for space enthusiasts, scientists, and anyone interested in the history and future of space exploration.

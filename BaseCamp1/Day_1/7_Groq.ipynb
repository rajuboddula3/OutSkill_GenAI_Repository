# %% [markdown]
# ### Groq Usage for LLM ###
# **Library Need**
# To use the APIs provided by the groq platform, the library 'groq' is required.
# Ensure to have performed 'pip install groq'
# The API key from your Groq account would be required to execute this code

# %%
# Import required class from Groq
from groq import Groq
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
Client = Groq ()

# Client = Groq (api_key='Your API Key')

# %% [markdown]
# **Invoke for chat Completion**
# >The APIs can be used for invoking LLM models available in Groq for chat completion
# >Try with differet models and different prompt messages

# %%
prompt = "Tell me what is special about 12-Apr"

# Prompt needs to be organised as message (list of dict)
messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = Client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    # model="llama-3.3-70b-specdec",
    stop=None,
    temperature=1.0
)

print (completion.choices[0].message.content)
# Out:
# April 12 is special for several reasons:
#
# 1. **Cosmonautics Day**: April 12 is celebrated as Cosmonautics Day in Russia and some other countries to commemorate the first human spaceflight by Yuri Gagarin on April 12, 1961.
# 2. **International Day of Human Space Flight**: The United Nations General Assembly declared April 12 as the International Day of Human Space Flight in 2011 to recognize the importance of space exploration and the contributions of space agencies and scientists worldwide.
# 3. **Yuri's Night**: April 12 is also known as Yuri's Night, a global celebration of space exploration and the achievements of Yuri Gagarin. It's a night to inspire people to pursue careers in science, technology, engineering, and mathematics (STEM) and to promote international cooperation in space exploration.
#
# These events make April 12 a significant date in the history of space exploration and a celebration of human achievements in space travel.

# %% [markdown]
# ### Groq Usage for LLM ###
# **Library Need**
# To use the APIs provided by the groq platform, the library 'groq' is required.
# Ensure to have performed 'pip install groq'
# The API key from your Groq account would be required to execute this code

# %%
# Import required class from Groq
from groq import Groq
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
Client = Groq ()

# Client = Groq (api_key='Your API Key') - Passing the api key of Groq

# %% [markdown]
# **Invoke for chat Completion**
# >The APIs can be used for invoking LLM models available in Groq for chat completion
# >Try with differet models and different prompt messages

# %%
prompt = "Tell me what is special about August 15th and 26th January in India"

# Prompt needs to be organised as message (list of dict)
messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = Client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    #model="llama-3.3-70b-specdec",
    stop=None,
    temperature=1.0
)

print (completion.choices[0].message.content)
# Out:
# In India, August 15th and January 26th are two very significant dates.
#
# **August 15th: Independence Day**
# August 15th is celebrated as Independence Day in India. It marks the day when India gained independence from British colonial rule in 1947. On this day, Jawaharlal Nehru, the first Prime Minister of India, hoisted the Indian national flag at the Red Fort in Delhi, marking the beginning of India's journey as a sovereign nation. The day is celebrated with great enthusiasm and patriotism across the country, with flag-hoisting ceremonies, parades, and cultural events.
#
# **January 26th: Republic Day**
# January 26th is celebrated as Republic Day in India. It commemorates the day when the Constitution of India came into effect in 1950, replacing the Government of India Act (1935) as the governing document of India. The Constitution of India was adopted by the Constituent Assembly on November 26, 1949, but it came into effect on January 26, 1950. The day is celebrated with a grand parade in New Delhi, showcasing India's military might, cultural diversity, and technological advancements. The parade is attended by the President of India, other dignitaries, and thousands of spectators.
#
# Both August 15th and January 26th are national holidays in India, and they are celebrated with great fervor and pride by Indians all over the world.

# %%
prompt = "Tell me about the FIFA World Cup finalist"

messages=[
    {
        "role": "user",
        "content": prompt
    }
]

completion = Client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    #model="llama-3.3-70b-specdec",
    stop=None,
    temperature=1.0
)

print (completion.choices[0].message.content)
# Out:
# The FIFA World Cup is an international soccer tournament held every four years, featuring national teams from all over the world. There have been a total of 22 FIFA World Cup finals, with the first one taking place in 1930.
#
# Here are some of the most recent FIFA World Cup finalists:
#
# 1. **2022 FIFA World Cup**: Argentina vs. France - Argentina won the tournament by defeating France 4-2 in a penalty shootout after the match ended 3-3 after extra time.
# 2. **2018 FIFA World Cup**: France vs. Croatia - France won the tournament by defeating Croatia 4-2 in the final.
# 3. **2014 FIFA World Cup**: Germany vs. Argentina - Germany won the tournament by defeating Argentina 1-0 in extra time.
# 4. **2010 FIFA World Cup**: Spain vs. Netherlands - Spain won the tournament by defeating Netherlands 1-0 in extra time.
# 5. **2006 FIFA World Cup**: Italy vs. France - Italy won the tournament by defeating France 5-3 in a penalty shootout after the match ended 1-1 after extra time.
#
# Some of the most successful teams in the FIFA World Cup finals include:
#
# * **Brazil**: 5-time winners (1958, 1962, 1970, 1994, 2002)
# * **Germany**: 4-time winners (1954, 1974, 1990, 2014)
# * **Italy**: 4-time winners (1934, 1938, 1982, 2006)
# * **Argentina**: 3-time winners (1978, 1986, 2022)
# * **Uruguay**: 2-time winners (1930, 1950)
# * **France**: 2-time winners (1998, 2018)
#
# These are just a few examples of the teams that have reached the FIFA World Cup final. The tournament is highly competitive, and many other teams have also had success in the competition.

# %% [markdown]
# ### Groq Usage for LLM ###
# **Library Need**
# To use the APIs provided by the groq platform, the library 'groq' is required.
# Ensure to have performed 'pip install groq'
# The API key from your Groq account would be required to execute this code

# %%
# Import required class from Groq
from groq import Groq
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
Client = Groq ()

# Client = Groq (api_key='Your API Key') - Passing the api key of Groq

# %% [markdown]
# **Invoke for chat Completion**
# >The APIs can be used for invoking LLM models available in Groq for chat completion
# >Try with differet models and different prompt messages

# %%
prompt = "Tell me what is special about 12-Apr"

# Prompt needs to be organised as message (list of dict)
messages=[
    {
        "role": "user",
        "content": prompt,
    }
]
completion = Client.chat.completions.create(
    messages=messages,
    model="llama-3.3-70b-versatile",
    # model="llama-3.3-70b-specdec",
    stop=None,
    temperature=1.0
)

print (completion.choices[0].message.content)
# Out:
# April 12th is a significant date for several reasons:
#
# 1. **Cosmonautics Day**: April 12th is celebrated as Cosmonautics Day in Russia and some other former Soviet countries. This day commemorates the first human spaceflight, which was achieved by Yuri Gagarin on April 12, 1961. Gagarin became the first person to journey into outer space when he orbited the Earth aboard the Vostok 1 spacecraft.
#
# 2. **International Day of Human Space Flight**: In 2011, the United Nations General Assembly declared April 12th as the International Day of Human Space Flight to commemorate the 50th anniversary of Yuri Gagarin's historic flight.
#
# 3. **Other events**: April 12th has also been notable for other historical events, such as the establishment of the first permanent English settlement in North America at Jamestown, Virginia, in 1607.
#
# Overall, April 12th is special because it marks a significant milestone in space exploration and is celebrated as a day of achievement in the field of cosmonautics.

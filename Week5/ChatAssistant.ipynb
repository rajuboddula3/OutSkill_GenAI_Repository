# %% [markdown]
# # **Building a Retrieval Augmented Generation (RAG) Based AI Chatbot**
#
# ## **1. Introduction to RAG**
#
# Retrieval Augmented Generation (RAG) is a powerful architectural pattern for building AI chatbots and other language model applications that can leverage external knowledge sources to provide more accurate, up-to-date, and contextually relevant responses.
#
# Traditional Large Language Models (LLMs) are trained on vast datasets, but their knowledge is static (frozen at the time of training) and they can sometimes "hallucinate" or generate plausible but incorrect information. RAG addresses these limitations by:
#
# 1. **Retrieving** relevant information from a specified knowledge base in real-time.
# 2. **Augmenting** the user's query with this retrieved information.
# 3. **Generating** a response based on both the original query and the augmented context.
#
# This allows the chatbot to access and utilize domain-specific, private, or rapidly changing information that was not part of its original training data.
#
# ## **2. Core Components of a RAG System**
#
# A typical RAG system comprises several key components:
#
# * **Knowledge Base (Data Corpus):** This is the collection of documents, data, or information that the chatbot will use to answer questions. It can be a set of text files, PDFs, web pages, database records, FAQs, articles, etc.
# * **Embedding Model:** This model converts text (from the knowledge base and user queries) into numerical representations called "embeddings" or "vectors." These embeddings capture the semantic meaning of the text, allowing for similarity comparisons. Popular choices include models like Sentence-BERT, OpenAI's Ada, or Cohere's embed models.
# * **Vector Database (Vector Store):** This specialized database is designed to store and efficiently query high-dimensional vectors (the embeddings). It allows for fast similarity searches to find the most relevant pieces of information from the knowledge base based on a query embedding. Examples include Pinecone, Weaviate, FAISS, Chroma, Milvus, or even some traditional databases with vector search capabilities.
# * **Retriever:** This component takes the user's query, converts it into an embedding using the embedding model, and then queries the vector database to find the "top-k" most similar document chunks or pieces of information from the knowledge base.
# * **Large Language Model (LLM) \- The Generator:** This is the core generative model (e.g., GPT-3.5/4, Llama, PaLM, Claude) that takes the original user query *and* the retrieved context (from the Retriever) and generates a coherent, natural language response.
# * **Orchestration/Prompting Layer:** This layer manages the overall workflow. It formats the user's query and the retrieved context into a suitable prompt for the LLM, ensuring the LLM understands how to use the provided information to answer the question.
#
# ## **3. Workflow of a RAG Chatbot**
#
# The typical interaction flow in a RAG chatbot is as follows:
#
# 1. **User Query:** The user asks the chatbot a question.
# 2. **Query Embedding:** The user's query is converted into a vector embedding by the embedding model.
# 3. **Information Retrieval:**
#    * The retriever uses this query embedding to search the vector database.
#    * The vector database returns the most semantically similar document chunks (contexts) from the knowledge base.
# 4. **Context Augmentation & Prompting:**
#    * The retrieved context(s) are combined with the original user query.
#    * This combined information is formatted into a prompt that instructs the LLM to answer the query based on the provided context.
# 5. **Response Generation:** The LLM processes the augmented prompt and generates a natural language response.
# 6. **User Receives Response:** The chatbot presents the LLM's generated answer to the user.
#
# ## **4. Steps to Build a RAG Chatbot**
#
# Building a RAG chatbot involves several key development stages:
#
# ### **Step 1: Data Preparation & Loading**
#
# * **Gather Your Data:** Collect all the documents and data sources that will form your knowledge base.
# * **Preprocess Data:** Clean the data (remove irrelevant characters, formatting issues).
# * **Chunking:** This is a crucial step. LLMs have context window limits. Large documents need to be broken down into smaller, manageable, and semantically coherent chunks. The size of these chunks can impact retrieval quality.
#   * **Strategies:** Fixed-size chunking, sentence-based chunking, recursive chunking, or content-aware chunking (e.g., by paragraphs or sections).
#   * **Overlap:** Often, a small overlap between chunks is introduced to ensure semantic continuity is not lost at chunk boundaries.
#
# ### **Step 2: Embedding Generation & Storage**
#
# * **Choose an Embedding Model:** Select an embedding model appropriate for your data and language.
# * **Generate Embeddings:** Process each chunk of your knowledge base through the embedding model to create its vector representation.
# * **Set up Vector Database:** Choose and configure a vector database.
# * **Index Embeddings:** Store these embeddings (along with their corresponding text chunks and any metadata) in the vector database, creating an index for efficient searching.
#
# ### **Step 3: Implement the Retriever**
#
# * **Query Embedding Function:** Create a function that takes a user query, uses the same embedding model from Step 2, and generates its embedding.
# * **Similarity Search Function:** Implement logic to take the query embedding and perform a similarity search (e.g., cosine similarity, dot product) against the indexed embeddings in the vector database. This function should return the top-k most relevant text chunks.
#
# ### **Step 4: Integrate the Large Language Model (Generator)**
#
# * **Choose an LLM:** Select an LLM suitable for your chatbot's desired capabilities and tone (e.g., OpenAI's API, a self-hosted open-source model).
# * **Prompt Engineering:** This is critical. Design a prompt template that effectively combines the user's original query with the retrieved context. The prompt should guide the LLM to:
#   * Answer the question based *only* on the provided context if possible.
#   * Indicate if the answer cannot be found in the context.
#   * Maintain a conversational tone.
#   * Example Prompt Snippet:
#
# ```
#
# Context:
# {retrieved_document_chunks}
#
# Question: {user_query}
#
# Answer the question based on the context provided above. If the context doesn't contain the answer, say "I don't have enough information to answer that."
#
# ```
#
# ### **Step 5: Build the Chat Interface & Orchestration**
#
# * **User Interface (UI):** Develop a front-end for users to interact with the chatbot (e.g., a web interface, integration into an existing messaging platform).
# * **Backend Logic (Orchestration):** Create the backend logic that ties all components together:
#   1. Receives user query from the UI.
#   2. Calls the retriever to get relevant context.
#   3. Constructs the prompt for the LLM.
#   4. Sends the prompt to the LLM API.
#   5. Receives the LLM's response.
#   6. Sends the response back to the UI.
# * **Conversation History (Optional but Recommended):** For multi-turn conversations, you might want to include conversation history in the prompt or use techniques to summarize past turns to provide context for follow-up questions.
#
# ## **5. Key Considerations and Best Practices**
#
# * **Chunking Strategy:** Experiment with different chunk sizes and overlap. Too small, and you lose context; too large, and you might introduce noise or exceed LLM context limits.
# * **Embedding Model Choice:** The quality of embeddings significantly impacts retrieval. Choose models trained on similar domains or fine-tune them if necessary.
# * **Retrieval Strategy:**
#   * **Top-k:** How many chunks to retrieve? Too few might miss the answer; too many can overwhelm the LLM or dilute the relevant information.
#   * **Similarity Threshold:** Only retrieve chunks above a certain similarity score to filter out irrelevant results.
#   * **Re-ranking:** Sometimes, a secondary, more sophisticated model (a re-ranker) is used to re-order the initial top-k retrieved chunks for better relevance before sending them to the LLM.
# * **Prompt Engineering:** Iteratively refine your prompts. The way you instruct the LLM to use the context is crucial for response quality and preventing hallucinations.
# * **Evaluation:**
#   * **Retrieval Metrics:** Precision, Recall, Mean Reciprocal Rank (MRR) for the retriever.
#   * **Generation Metrics:** BLEU, ROUGE (less ideal for conversational AI), or human evaluation for the generated responses.
#   * **End-to-End Evaluation:** Assess the overall quality, relevance, and factuality of the chatbot's answers. Frameworks like RAGAs can be helpful.
# * **Handling "I don't know":** Ensure your system can gracefully handle queries for which no relevant information exists in the knowledge base, rather than forcing an answer.
# * **Scalability:** Consider the scalability of your vector database and LLM inference as your knowledge base and user traffic grow.
# * **Maintenance & Updates:** Plan how you will update the knowledge base, re-generate embeddings, and re-index the vector database as new information becomes available.
# * **Cost Management:** Using LLM APIs and vector databases can incur costs. Optimize your system for efficiency.
#
# ## **6. Benefits of RAG**
#
# * **Reduced Hallucinations:** By grounding responses in retrieved factual data, RAG significantly reduces the likelihood of the LLM making things up.
# * **Access to Current Information:** LLMs can answer questions based on the latest information available in the knowledge base, unlike their static training data.
# * **Domain-Specific Knowledge:** Enables chatbots to become experts in specific domains by feeding them relevant documents (e.g., medical texts, legal documents, internal company policies).
# * **Transparency and Explainability:** It's often possible to cite the source documents used to generate an answer, increasing trust and allowing users to verify information.
# * **Cost-Effective Customization:** Less expensive than fine-tuning an entire LLM for a new domain, as it primarily involves managing and embedding the knowledge base.
#
# ## **7. Potential Challenges**
#
# * **Retrieval Quality:** The entire system heavily relies on the retriever's ability to find the truly relevant information. Poor retrieval leads to poor generation.
# * **Chunking Dilemmas:** Finding the optimal chunking strategy can be challenging and data-dependent.
# * **Integration Complexity:** Connecting various components (embedding models, vector DBs, LLMs) requires careful engineering.
# * **Latency:** The multi-step process (embedding, retrieval, generation) can introduce latency. Optimizations are often needed.
# * **Evaluation Complexity:** Evaluating the end-to-end performance of RAG systems comprehensively can be difficult.

# %% [markdown]
# The pre-req steps to use the Gemini API key with Python:
#
# 1.  **Get API Key:** Go to [aistudio.google.com](https://aistudio.google.com/), sign in, and create/copy your API key (secure it immediately).
# 2.  **Install Library:** In your terminal, run `pip install -q -U google-generativeai`.
# 3.  **Set API Key Securely:**
#     * **Recommended:** Set it as an environment variable (e.g., `export GOOGLE_API_KEY="YOUR_KEY"` in terminal/shell config).
#     * **Colab:** Use Colab Secrets to store `GOOGLE_API_KEY`.
# 4.  **Configure in Python:** In your script, retrieve the key (e.g., `os.getenv('GOOGLE_API_KEY')` or `userdata.get('GOOGLE_API_KEY')`) and then use `genai.configure(api_key=YOUR_KEY)`.
#
# [Gemini API Key](https://aistudio.google.com/u/1/apikey)

# %%
# Load data
# https://www.kaggle.com/datasets/fajobgiua/indian-food-dataset?resource=download
import os
import re
import json
import time

import httpx  # the transport google-genai runs on -- needed to catch timeouts
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.auto import tqdm

from langchain_core.documents import Document
# Load models and Initialize Vector Store
from langchain_huggingface import HuggingFaceEmbeddings
# `Qdrant` is the deprecated wrapper -> `QdrantVectorStore` is the current one
from langchain_qdrant import QdrantVectorStore  # Qdrant Vector Store Wrapper
from qdrant_client import models as qdrant_models
from google import genai  # Gemini SDK -> pip install google-genai
from google.genai import errors as genai_errors
from google.genai import types as genai_types
from dotenv import load_dotenv  # For loading API key from a .env file

load_dotenv()

tqdm.pandas(desc="Generating Documents")

cleaning_pattern = r'[^a-zA-Z0-9]'

columns = ['TranslatedRecipeName', 'TranslatedIngredients',
           'PrepTimeInMins', 'CookTimeInMins', 'TotalTimeInMins', 'Servings',
           'Cuisine', 'Course', 'Diet', 'TranslatedInstructions', 'URL',
           'ComplexityLevel', 'MainIngredient']

doc_columns = ['score', 'page_content',]

result_columns = [
    'TranslatedRecipeName',
    'page_content',
    'PrepTimeInMins',
    'CookTimeInMins',
    'TotalTimeInMins',
    'Servings',
    'Cuisine',
    'Diet',
    'ComplexityLevel',
    'MainIngredient',
    'score',
    'rerank_score',
]


# The exact metadata vocabulary Qdrant can match on. Used both to build the
# prompt in `generate_metadata` and to validate what comes back, so the two
# can never drift apart.
allowed_metadata = {
    'Cuisine': [
        'Indian', 'Kerala Recipes', 'Oriya Recipes', 'Continental',
        'Chinese', 'Konkan', 'Chettinad', 'Mexican', 'Kashmiri',
        'South Indian Recipes', 'North Indian Recipes', 'Andhra',
        'Gujarati Recipes',
    ],
    'Diet': [
        'Vegetarian', 'High Protein Vegetarian', 'Non Vegeterian',
        'Eggetarian', 'Diabetic Friendly', 'High Protein Non Vegetarian',
        'Gluten Free', 'Sugar Free Diet', 'No Onion No Garlic (Sattvic)',
        'Vegan',
    ],
    'ComplexityLevel': ['Medium', 'Hard'],
}


def convert_to_doc(row):
    doc = Document(
        page_content=f'''
# Recipe Name: {row['TranslatedRecipeName']}
> URL: {row['URL']}

## Ingredients:

{row['TranslatedIngredients']}

## Instructions:

{row['TranslatedInstructions']}
''',
        metadata={
            'TranslatedRecipeName': row['TranslatedRecipeName'],
            'PrepTimeInMins': row['PrepTimeInMins'],
            'CookTimeInMins': row['CookTimeInMins'],
            'TotalTimeInMins': row['TotalTimeInMins'],
            'Servings': row['Servings'],
            'Cuisine': row['Cuisine'],
            'Course': row['Course'],
            'Diet': row['Diet'],
            'ComplexityLevel': row['ComplexityLevel'],
            'MainIngredient': row['MainIngredient'],
        }
    )

    return doc


def parse_json_response(text, default=None):
    """Extract JSON from an LLM reply, with or without a ```json fence.

    Splitting on the word `json` breaks whenever the model answers without a
    fence (or mentions "json" in prose), so key off the fence itself. The model
    also ignores "respond with json" often enough -- usually answering with a
    numbered list -- that an unparseable reply has to be a survivable outcome
    rather than a crash deep inside `search`, so it returns `default` instead.
    """
    cleaned = text.strip()
    if '```' in cleaned:
        block = cleaned.split('```')[1]
        if block.startswith('json'):
            block = block[len('json'):]
        cleaned = block.strip()

    try:
        return json.loads(cleaned)
    except json.JSONDecodeError:
        pass

    # second chance: the outermost {...} or [...] embedded in a prose reply
    for opener, closer in (('{', '}'), ('[', ']')):
        start, end = cleaned.find(opener), cleaned.rfind(closer)
        if start != -1 and end > start:
            try:
                return json.loads(cleaned[start:end + 1])
            except json.JSONDecodeError:
                continue

    return default


def normalise_metadata(raw):
    """Coerce whatever the LLM returned into a clean {field: [values]} dict.

    A multi-part query makes the model answer with a *list* of per-subquery
    dicts as often as a single dict, and it happily invents field names and
    values. Qdrant only does exact matches, so anything outside
    `allowed_metadata` can never match and is dropped instead of silently
    emptying the result set.
    """
    candidates = raw if isinstance(raw, list) else [raw]

    metadata = {}
    for candidate in candidates:
        if not isinstance(candidate, dict):
            continue
        for key, value in candidate.items():
            if key not in allowed_metadata:
                continue
            values = value if isinstance(value, (list, tuple, set)) else [value]
            keep = [v for v in values if v in allowed_metadata[key]]
            # union the sub-filters -> a MatchAny, so a multi-part query stays
            # satisfiable instead of demanding Vegetarian AND Non Vegeterian
            metadata[key] = sorted(set(metadata.get(key, [])) | set(keep))

    return {key: values for key, values in metadata.items() if values}


def to_qdrant_filter(metadata_filter):
    """Turn a plain dict such as {'Cuisine': 'Indian'} into a Qdrant filter object.

    QdrantVectorStore stores LangChain metadata under the `metadata` payload key,
    so every field has to be addressed as `metadata.<field>`. A list of accepted
    values becomes a `MatchAny`, a single value a `MatchValue`. An empty dict
    means "no filtering" -> None.
    """
    if not isinstance(metadata_filter, dict) or not metadata_filter:
        return None

    def to_condition(key, value):
        if isinstance(value, (list, tuple, set)):
            match = qdrant_models.MatchAny(any=list(value))
        else:
            match = qdrant_models.MatchValue(value=value)
        return qdrant_models.FieldCondition(key=f'metadata.{key}', match=match)

    return qdrant_models.Filter(
        must=[to_condition(key, value) for key, value in metadata_filter.items()]
    )


def generate_metadata(search_query, llm):
    available = '\n'.join(
        f"    - '{field}': one of {values}"
        for field, values in allowed_metadata.items()
    )

    meta_prompt = f'''
    Given below the user request for queries, create metadata filter dictionary for the search.

    user query: {search_query}

    > provide only and only a simple phrase for the user query, do not add any other information or context.
    > this output will be used to filter the recipes.

    available metadata:
{available}

    We can do exact match only, so only ever use the values listed above.

    respond with a single flat json object mapping field -> value (or field ->
    list of values). Do not wrap it in a list and do not add any other
    information or context.
    '''

    resp = llm.generate_content(meta_prompt).text
    # the model returns a list of per-subquery dicts about as often as one dict,
    # and sometimes no json at all -- filtering is an optimisation, so an
    # unusable answer just means "search without a filter"
    metadata = normalise_metadata(parse_json_response(resp, default={}))

    return metadata


def rewrite_query(search_query, llm):
    prompt = f'''
    Given below the user request for queries regarding Indian food recipes, rephrase and expand the query to a more search friendly term.

    user query: {search_query}

    > provide only and only a simple phrase for the user query, do not add any other information or context.
    > this output will be used to search the database for recipes.
    '''
    resp = llm.generate_content(prompt).text
    return resp


def break_query(search_query, llm):
    subquery_prompt = f'''
    Given below the user request for queries, break down the query into multiple subqueries.
    user query: {search_query}
    > provide only and only a simple phrase for the user query, do not add any other information or context.
    > this output will be used to search the database for recipes.

    > respond with a valid json array of strings, do not add any other information or context.
    '''

    resp = llm.generate_content(subquery_prompt).text
    subqueries = parse_json_response(resp)

    if subqueries is None:
        # no json came back -- the model usually answers with a numbered or
        # bulleted list instead, which is perfectly usable once stripped
        subqueries = [
            re.sub(r'^\s*(?:[-*\u2022]|\d+[.)])\s*', '', line)
            for line in resp.splitlines()
        ]
    # a bare string would be iterated character by character by the caller
    if isinstance(subqueries, str):
        subqueries = [subqueries]
    return [str(q).strip() for q in subqueries if str(q).strip()] or [search_query]


def rerank_results(
        search_query,
        searched_df,
        reranking_model
):
    new_doc_embeddings = np.array(
        # `.tolist()` -> the embedding model expects a list of strings
        reranking_model.embed_documents(searched_df.page_content.tolist())
    )

    query_embedding = np.array(
        reranking_model.embed_query(search_query)
    )

    similarity_scores = cosine_similarity(
        query_embedding.reshape(1, -1),
        new_doc_embeddings
    )
    searched_df['rerank_score'] = similarity_scores[0].tolist()
    return searched_df


def search(
        search_query,
        llm,
        vector_store,
        reranking_model,
        n_results=10,
        similarity_threshold=0.1,
        flag_rewrite_query=True,
        flag_ai_metadata=True,
        flag_break_query=True,
        flag_rerank_results=True,
):
    """
    Search for the given query in the vector store and return the top n results.
    """
    metadata = {}  # Empty metadata
    subqueries = [search_query]

    if flag_rewrite_query:
        search_query = rewrite_query(search_query, llm)

    if flag_ai_metadata:
        metadata = generate_metadata(search_query, llm)

    if flag_break_query:
        subqueries = break_query(search_query, llm)

    ret_docs = []

    for subquery in subqueries:
        ret_docs += vector_store.similarity_search_with_score(
            subquery,
            k=n_results,
            score_threshold=similarity_threshold,
            filter=to_qdrant_filter(metadata)
        )

    searched_df = pd.DataFrame(
        [
            {
                'score': score,
                **doc.metadata,
                'page_content': doc.page_content,
            } for doc, score in ret_docs
        ],
        columns=doc_columns+columns
    )

    # A filter can rule out every recipe -> return the empty frame rather than
    # letting the reranker embed an empty list.
    if searched_df.empty:
        searched_df['rerank_score'] = []
        return searched_df[result_columns]

    searched_df = searched_df.groupby(
        'TranslatedRecipeName').first().reset_index()
    searched_df['rerank_score'] = searched_df['score']

    if flag_rerank_results:
        searched_df = rerank_results(
            search_query,
            searched_df=searched_df,
            reranking_model=reranking_model,
        ).sort_values(
            'rerank_score',
            ascending=False,
        )

    return searched_df.head(n_results).round(2)[result_columns]


def as_cards(df):
    """Render each result row as a compact markdown card.

    `Series.to_markdown()` lays the row out as a table and pads every field to
    the width of the widest one -- and `page_content` is a few thousand
    characters, so all 12 fields got padded to that. A 50-row result set came
    out at 1.7M characters (~91k tokens) of almost entirely whitespace, which
    on its own blows the free tier's per-minute token budget. Same fields, same
    values, ~14x fewer characters.
    """
    if df.empty:
        return []
    return df.apply(
        lambda row: '\n'.join(f'**{field}**: {value}'
                              for field, value in row.items()),
        axis=1,
    ).to_list()

# %%
# Initialize system
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise RuntimeError(
        "GOOGLE_API_KEY is not set. Add it to Week5/.env as GOOGLE_API_KEY=..."
    )

# google-genai sets NO HTTP timeout by default, so a stalled connection blocks
# the whole notebook forever (the request sits in SSL_read and never returns).
# Cap it -- a slow request is far better than a hung kernel.
client = genai.Client(
    api_key=api_key,
    http_options=genai_types.HttpOptions(timeout=120_000),  # milliseconds
)

# Free-tier quotas are per model and small (`gemini-2.5-flash` allows only
# 20 requests/day) and this notebook makes dozens of calls, so work through a
# list of models: retry the ones that are merely rate limited, and move on to
# the next model only once a model's *daily* allowance is gone.
model_names = [
    'gemini-2.5-flash-lite',
    'gemini-3.1-flash-lite',
    'gemini-flash-lite-latest',
    'gemini-2.5-flash',
]


class GeminiModel:
    """Thin wrapper so every cell below can keep calling
    `model.generate_content(prompt).text` on the current google-genai SDK.

    It also handles the ways the free tier says "no":
      * per-minute rate limit / 5xx / network timeout -> wait (honouring the
        `retryDelay` the API itself returns) and try the same model again
      * still failing after `max_retries`              -> set the model aside
        for this call and try the next one, then hand it back
      * per-day quota exhausted                        -> retrying is pointless,
        so drop that model for the rest of the session
    """

    def __init__(self, client, model_names, max_retries=5):
        self.client = client
        self.model_names = list(model_names)
        self.max_retries = max_retries
        self.exhausted = []

    @property
    def model_name(self):
        return self.model_names[0] if self.model_names else None

    @staticmethod
    def _quota_info(exc):
        """(only_per_day_quota_left, retry_delay_seconds) read out of the error body.

        A 429 can report several violations at once. Waiting only helps when a
        per-minute one is among them, so a model counts as used up for the day
        only when *every* violation is a per-day one.
        """
        quota_ids, retry_delay = [], None
        details = (getattr(exc, 'details', None) or {}).get('error', {}).get('details', [])
        for detail in details:
            kind = detail.get('@type', '')
            if kind.endswith('QuotaFailure'):
                quota_ids += [v.get('quotaId', '') for v in detail.get('violations', [])]
            elif kind.endswith('RetryInfo'):
                retry_delay = float(str(detail.get('retryDelay', '0s')).rstrip('s') or 0)

        per_day_only = bool(quota_ids) and all('PerDay' in q for q in quota_ids)
        return per_day_only, retry_delay

    def generate_content(self, prompt):
        # A model set aside here is only *temporarily* unusable (per-minute
        # limit, network wobble). Dropping it for good the way an exhausted
        # daily quota is dropped would burn through every model on a transient
        # burst, so it is handed back once this call is over.
        deferred = []
        try:
            while self.model_names:
                model_name = self.model_names[0]
                for attempt in range(self.max_retries):
                    last_attempt = attempt == self.max_retries - 1
                    try:
                        return self.client.models.generate_content(
                            model=model_name,
                            contents=prompt,
                        )
                    except httpx.HTTPError as exc:
                        # a timeout is not an API error, so it arrives here
                        if last_attempt:
                            print(f'  {model_name}: {type(exc).__name__}, '
                                  'trying the next model')
                            deferred.append(self.model_names.pop(0))
                            break
                        wait = 2 ** attempt
                        print(f'  {type(exc).__name__} talking to Gemini, retrying '
                              f'in {wait}s ({attempt + 1}/{self.max_retries - 1})')
                        time.sleep(wait)
                    except (genai_errors.ServerError, genai_errors.ClientError) as exc:
                        per_day_only, retry_delay = self._quota_info(exc)
                        retryable = getattr(exc, 'code', None) in (429, 500, 502, 503, 504)

                        if per_day_only or (retryable and last_attempt):
                            reason = ('daily quota used up' if per_day_only
                                      else f'still failing with {exc.code}')
                            print(f'  {model_name}: {reason}, trying the next model')
                            retired = self.model_names.pop(0)
                            (self.exhausted if per_day_only else deferred).append(retired)
                            break
                        if not retryable:
                            raise

                        wait = retry_delay or 2 ** attempt
                        print(f'  {exc.code} from Gemini, retrying in {wait}s '
                              f'({attempt + 1}/{self.max_retries - 1})')
                        time.sleep(wait)

            raise RuntimeError(
                'No Gemini model could answer this request.\n'
                f'  out of daily free-tier quota: {", ".join(self.exhausted) or "none"}\n'
                f'  rate limited / unreachable:   {", ".join(deferred) or "none"}\n'
                'Wait for the daily reset (midnight Pacific time), enable billing '
                'on the project, or use a different GOOGLE_API_KEY.'
            )
        finally:
            # hand the temporarily-unusable models back for the next call
            self.model_names.extend(deferred)


model = GeminiModel(client, model_names)
model_name = model.model_name  # the model actually in use
print('using model:', model_name)


df = pd.read_csv('./IndianFoodDataset.csv', ).set_index('Srno')[columns]

# `.tolist()` -> the vector store expects a list of Documents, not a pandas Series
data = df[:].progress_apply(convert_to_doc, axis=1).tolist()


model_768 = HuggingFaceEmbeddings(
    model_name="sentence-transformers/LaBSE",
)

model_384 = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
)

model_64 = HuggingFaceEmbeddings(
    model_name="ClovenDoug/tiny_64_all-MiniLM-L6-v2",
)


vector_store_unchunked = QdrantVectorStore.from_documents(
    data,
    model_384,
    collection_name="indian-food-metadata",
    location=':memory:',
)
# Out:
# using model: gemini-2.5-flash-lite
# Generating Documents:   0%|          | 0/6871 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
search_query = 'Healthy Non Veg, Non Spicy, Easy to Cook, 30 Mins, 2 Servings'
results = search(
    search_query,
    llm=model,
    reranking_model=model_768,
    vector_store=vector_store_unchunked,
    n_results=5,
    similarity_threshold=0.5,
    flag_rewrite_query=False,
    flag_ai_metadata=False,
    flag_break_query=False,
    flag_rerank_results=False,
)

results
# Out:
#                                 TranslatedRecipeName  \
# 0                                   Dal Vangi Recipe
# 1                        Goan Masoorchi Usali Recipe
# 2  Udupi Style Mixed Vegetable Sambar Recipe (Len...
# 3                            Veg Chilli Milli Recipe
# 4               Vermicelli Biryani (Recipe in Hindi)
#
#                                         page_content  PrepTimeInMins  \
# 0  \n# Recipe Name:  Dal Vangi Recipe\n> URL: htt...              10
# 1  \n# Recipe Name: Goan Masoorchi Usali Recipe\n...              10
# 2  \n# Recipe Name: Udupi Style Mixed Vegetable S...              20
# 3  \n# Recipe Name: Veg Chilli Milli Recipe\n> UR...              20
# 4  \n# Recipe Name: Vermicelli Biryani (Recipe in...              15
#
#    CookTimeInMins  TotalTimeInMins  Servings                Cuisine  \
# 0              45               55         4  Maharashtrian Recipes
# 1              35               45         2           Goan Recipes
# 2              30               50         4            Mangalorean
# 3              30               50         4   North Indian Recipes
# 4              15               30         4                 Indian
#
#                       Diet ComplexityLevel MainIngredient  score  rerank_score
# 0  High Protein Vegetarian            Hard            dal   0.64          0.64
# 1  High Protein Vegetarian            Hard        lentils   0.62          0.62
# 2               Vegetarian            Hard           Dal)   0.62          0.62
# 3               Vegetarian            Hard       shredded   0.63          0.63
# 4               Vegetarian            Hard        roasted   0.63          0.63

# %%
search_query = 'Healthy Non Veg, Non Spicy, Easy to Cook, 30 Mins, 2 Servings'
results = search(
    search_query,
    llm=model,
    reranking_model=model_768,
    vector_store=vector_store_unchunked,
    n_results=5,
    similarity_threshold=0.5,
    flag_rewrite_query=True,
    flag_ai_metadata=True,
    flag_break_query=True,
    flag_rerank_results=True,
)

results
# Out:
#                                 TranslatedRecipeName  \
# 3  Crispy and Spicy Chilli Chicken Recipe - India...
# 1       Bengali style meat broth recipe-mutton curry
# 4                       Goan Chicken Vindaloo Recipe
# 2  Chettinad Mutton Chops Kuzhambu Recipe-Mutton ...
# 5              Kerala Style Mutton Pepper Fry Recipe
#
#                                         page_content  PrepTimeInMins  \
# 3  \n# Recipe Name: Crispy and Spicy Chilli Chick...              10
# 1  \n# Recipe Name: Bengali style meat broth reci...             180
# 4  \n# Recipe Name: Goan Chicken Vindaloo Recipe\...              10
# 2  \n# Recipe Name: Chettinad Mutton Chops Kuzham...              10
# 5  \n# Recipe Name: Kerala Style Mutton Pepper Fr...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings          Cuisine            Diet  \
# 3              15               25         5           Indian  Non Vegeterian
# 1              45              225         5  Bengali Recipes  Non Vegeterian
# 4              40               50         5     Goan Recipes  Non Vegeterian
# 2              60               70         4        Chettinad  Non Vegeterian
# 5              60               70         3   Kerala Recipes  Non Vegeterian
#
#   ComplexityLevel MainIngredient  score  rerank_score
# 3            Hard        Chicken   0.61          0.24
# 1            Hard         Mutton   0.51          0.20
# 4            Hard         pieces   0.59          0.19
# 2            Hard          chops   0.58          0.15
# 5            Hard         Mutton   0.58          0.15

# %%
user_test_messages = [
    'I want to eat something spicy, non oily and quick to cook.',
    'I am looking for a recipe that is healthy and easy to cook.',
    'I want to eat something that is non vegetarian, quick to cook and spicy.',
    'I am looking for a recipe that is gluten free and easy to cook.',
    'I want to eat something that is diabetic friendly and quick to cook.',
    'I am looking for a recipe that is high protein vegetarian and easy to cook.',
]

# %%
# Ultra Simple Chat Bot
from tqdm.auto import tqdm


prompt = '''You are a friendly and helpful assistant.
Reply to user queries in a friendly and helpful manner, but in the simplest way possible.
Best to keep responses short and to the point.

User Query: {user_message}

Chat History:
{chat_history}

'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    # format into a NEW variable -- reassigning `prompt` would
    # destroy the template after the first iteration
    filled_prompt = prompt.format(
        user_message=user_message,
        chat_history='\n'.join(
            [
                f"{msg['role']}: {msg['content']}"
                for msg in chat_messages
            ]
        ),
    )

    resp = model.generate_content(filled_prompt).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
# | user                                                                        | assistant                                                                                                |
# |:----------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                          |
# |                                                                             | How about some spicy chili noodles? They're super fast and you can control the oil! 😊                   |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                          |
# |                                                                             | Sure! How about a simple baked salmon with roasted vegetables? It's healthy, easy, and delicious! 🐟🥕🥦 |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                          |
# |                                                                             | How about some spicy chicken stir-fry? It's fast and you can add lots of chili! 🌶️🍗                     |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                          |
# |                                                                             | Sure! How about some gluten-free chicken and veggie stir-fry? It's quick and easy! 🥢                    |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                          |
# |                                                                             | How about some grilled chicken breast with a side salad? It's super fast and good for you! 🥗🍗          |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                          |
# |                                                                             | Sure! How about some lentil soup? It's packed with protein and super simple to make! 🍲                  |

# %%
# Lets Add in LLM persona and Objective
from tqdm.auto import tqdm

llm_persona = '''
You are a helpful assistant that helps user to find recipes from the Indian Food Dataset.
Your pesona is polite, friendly and helpful.
You are not a chef, you are a recipe search assistant.

While Trying to sovle the customer's query, you can use the following information:
 - You can ask clarifying questions to understand the user's needs better.
 - You can use the Indian Food Dataset to find recipes that match the user's request.
 - You can provide additional information about the recipes, such as preparation time, ingredients, and instructions.
 - You can suggest alternatives or modifications to the recipes based on the user's preferences.

You are not allowed to:
 - Provide medical or dietary advice.
 - Make assumptions about the user's dietary restrictions or preferences without asking.
 - Provide personal opinions or recommendations that are not based on the dataset.
 - Provide recipes that are not in the Indian Food Dataset.
 - Provide recipes that are not relevant to the user's query.
'''

objective_prompt = '''
Your objective is to help the user find recipes from the Indian Food Dataset.
Your hidden side task is also to suggest, cross sell and/upsell dishes.
'''

prompt = '''
Your persona:
{llm_persona}

Your objective:
{objective_prompt}

User Query: {user_message}

Chat History:
{chat_history}

'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    # format into a NEW variable -- reassigning `prompt` would
    # destroy the template after the first iteration
    filled_prompt = prompt.format(
        llm_persona=llm_persona,
        objective_prompt=objective_prompt,
        user_message=user_message,
        chat_history='\n'.join(
            [
                f"{msg['role']}: {msg['content']}"
                for msg in chat_messages
            ]
        ),
    )

    resp = model.generate_content(filled_prompt).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
#   429 from Gemini, retrying in 2.0s (1/4)
#   429 from Gemini, retrying in 2s (2/4)
#   429 from Gemini, retrying in 58.0s (3/4)
# | user                                                                        | assistant                                                                                                                                                                                                                                  |
# |:----------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                                                                                                                                                            |
# |                                                                             | Hello there! I'd be happy to help you find a delicious Indian recipe that's spicy, not too oily, and quick to prepare.                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | To narrow down our search, could you tell me if you have any specific vegetables or proteins in mind that you'd like to use? Also, are you looking for a main dish, a side dish, or perhaps a snack?                                       |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                                                                                                                                                            |
# |                                                                             | Hello again! It's wonderful that you're looking for something healthy and easy to cook. I can certainly help you with that from our Indian Food Dataset.                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | To make sure I find the perfect recipe for you, could you tell me a little more about what you have in mind? For example:                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | *   Are there any specific **vegetables or ingredients** you'd like to use, or perhaps any you'd like to avoid?                                                                                                                            |
# |                                                                             | *   Are you looking for a **main course, a side dish, or a snack**?                                                                                                                                                                        |
# |                                                                             | *   Do you have any **preferred cooking methods** in mind (like stir-frying, steaming, or baking)?                                                                                                                                         |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | Once I have a bit more information, I can suggest some fantastic options for you!                                                                                                                                                          |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                                                                                                                                                            |
# |                                                                             | Hello there! I'd be happy to help you find a delicious Indian recipe that's non-vegetarian, quick to cook, and spicy!                                                                                                                      |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | To help me find the perfect recipe for you, could you tell me if you have any specific non-vegetarian ingredients in mind, such as chicken, lamb, fish, or something else? Also, are you looking for a main dish, a side dish, or a snack? |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                                                                                                                                                            |
# |                                                                             | Hello there! I can certainly help you find a gluten-free and easy-to-cook recipe from our Indian Food Dataset.                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | To make sure I find the best match for you, could you tell me a little more about your preferences?                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | *   Are you looking for a **main course, a side dish, or a snack**?                                                                                                                                                                        |
# |                                                                             | *   Do you have any particular **vegetables or proteins** you'd like to include or avoid?                                                                                                                                                  |
# |                                                                             | *   Are there any specific **flavor profiles** you enjoy, besides being gluten-free and easy? For example, do you prefer something mild, savory, or perhaps with a hint of sweetness?                                                      |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | Once I have a better idea, I can suggest some wonderful options for you!                                                                                                                                                                   |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                                                                                                                                                            |
# |                                                                             | Hello there! I'd be delighted to help you find a diabetic-friendly and quick-to-cook recipe from our Indian Food Dataset.                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | To make sure I find the perfect dish for you, could you tell me a little more about what you're looking for? For instance:                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | *   Are you interested in a **main course, a side dish, or perhaps a snack**?                                                                                                                                                              |
# |                                                                             | *   Do you have any **specific vegetables or proteins** in mind that you'd like to use, or any you'd prefer to avoid?                                                                                                                      |
# |                                                                             | *   Are there any **particular flavors** you enjoy (e.g., savory, mildly spiced, etc.)?                                                                                                                                                    |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | Once I have a better idea of your preferences, I can suggest some wonderful options for you!                                                                                                                                               |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                                                                                                                                                            |
# |                                                                             | Hello there! I'd be happy to help you find a high-protein, vegetarian, and easy-to-cook recipe from our Indian Food Dataset. That sounds like a wonderful combination!                                                                     |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | To make sure I find the best fit for you, could you tell me:                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | *   Are there any specific **vegetables or legumes** you particularly enjoy or would like to use? (e.g., lentils, chickpeas, paneer, tofu, spinach, cauliflower)                                                                           |
# |                                                                             | *   Are you looking for a **main dish, a side dish, or perhaps a snack**?                                                                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                            |
# |                                                                             | Once I have a little more information, I can suggest some delicious options for you!                                                                                                                                                       |

# %%
# Lets Add in RAG Basic
from tqdm.auto import tqdm

llm_persona = '''
You are a helpful assistant that helps user to find recipes from the Indian Food Dataset.
Your pesona is polite, friendly and helpful.
You are not a chef, you are a recipe search assistant.

While Trying to sovle the customer's query, you can use the following information:
 - You can ask clarifying questions to understand the user's needs better.
 - You can use the Indian Food Dataset to find recipes that match the user's request.
 - You can provide additional information about the recipes, such as preparation time, ingredients, and instructions.
 - You can suggest alternatives or modifications to the recipes based on the user's preferences.

You are not allowed to:
 - Provide medical or dietary advice.
 - Make assumptions about the user's dietary restrictions or preferences without asking.
 - Provide personal opinions or recommendations that are not based on the dataset.
 - Provide recipes that are not in the Indian Food Dataset.
 - Provide recipes that are not relevant to the user's query.
'''

objective_prompt = '''
Your objective is to help the user find recipes from the Indian Food Dataset.
Your hidden side task is also to suggest, cross sell and/upsell dishes.
'''

prompt = '''
Your persona:
{llm_persona}

Your objective:
{objective_prompt}

User Query: {user_message}

Chat History:
{chat_history}

Searched Context from Database:
{context}
'''

rag_prompt = '''
User Query: {user_message}
Chat History:
{chat_history}
'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    chat_history = '\n'.join(
        [
            f"{msg['role']}: {msg['content']}"
            for msg in chat_messages
        ]
    )

    results = search(
        rag_prompt.format(
            user_message=user_message,
            chat_history=chat_history,
        ),
        llm=model,
        vector_store=vector_store_unchunked,
        reranking_model=model_768,
        n_results=5,
        similarity_threshold=0.5,
        flag_rewrite_query=False,
        flag_ai_metadata=False,
        flag_break_query=False,
        flag_rerank_results=False,
    )
    context = '\n---\n'.join(as_cards(results))

    # format into a NEW variable -- reassigning `prompt` would
    # destroy the template after the first iteration
    filled_prompt = prompt.format(
        llm_persona=llm_persona,
        objective_prompt=objective_prompt,
        user_message=user_message,
        chat_history=chat_history,
        context=context,
    )

    resp = model.generate_content(filled_prompt).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
# | user                                                                        | assistant                                                                                                                                                                                  |
# |:----------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                                                                                                            |
# |                                                                             | Hello there! I'd be delighted to help you find a delicious and spicy, non-oily, and quick recipe from our Indian Food Dataset!                                                             |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | To help me narrow down the search, could you tell me a little more about what you're in the mood for? For example:                                                                         |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | *   **Are you looking for a vegetarian or non-vegetarian dish?**                                                                                                                           |
# |                                                                             | *   **Do you have any specific ingredients in mind that you'd like to use or avoid?**                                                                                                      |
# |                                                                             | *   **What kind of meal are you looking for (e.g., a main course, a side dish, a snack)?**                                                                                                 |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Once I have a better idea, I can look for something perfect for you!                                                                                                                       |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                                                                                                            |
# |                                                                             | Hello there! I'd be delighted to help you find a delicious, healthy, and easy-to-cook recipe from our Indian Food Dataset.                                                                 |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | To assist you better, could you tell me a bit more about what you're looking for? For example:                                                                                             |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | *   **Are you looking for a vegetarian or non-vegetarian dish?**                                                                                                                           |
# |                                                                             | *   **Do you have any specific ingredients you'd like to use or any you'd like to avoid?**                                                                                                 |
# |                                                                             | *   **What kind of meal are you hoping to prepare (e.g., a main course, a side dish, a snack)?**                                                                                           |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Once I have this information, I can help you find the perfect recipe!                                                                                                                      |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                                                                                                            |
# |                                                                             | Hello there! I understand you're looking for a non-vegetarian, quick-to-cook, and spicy recipe. I'd be happy to help you find something delicious from our Indian Food Dataset!            |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | To make sure I find the perfect recipe for you, could you tell me:                                                                                                                         |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | *   **Do you have any specific types of non-vegetarian protein in mind, like chicken, lamb, or fish?**                                                                                     |
# |                                                                             | *   **Are there any particular vegetables or ingredients you'd like to include or avoid?**                                                                                                 |
# |                                                                             | *   **What kind of meal are you planning to make? Is it a main course, a snack, or something else?**                                                                                       |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Once I have a bit more information, I can search our dataset for a fantastic recipe!                                                                                                       |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                                                                                                            |
# |                                                                             | Hello there! I can certainly help you find some gluten-free and easy-to-cook recipes from our Indian Food Dataset.                                                                         |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | To make sure I suggest the best options for you, could you tell me:                                                                                                                        |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | *   **Are you looking for a vegetarian or non-vegetarian dish?**                                                                                                                           |
# |                                                                             | *   **Do you have any specific ingredients you'd like to use or avoid?**                                                                                                                   |
# |                                                                             | *   **What kind of meal are you hoping to prepare (e.g., a main course, a side dish, a snack)?**                                                                                           |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Once I have this information, I can search our dataset for the perfect recipe!                                                                                                             |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                                                                                                            |
# |                                                                             | Hello there! I understand you're looking for something diabetic-friendly and quick to cook. I can certainly help you with that!                                                            |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Based on the recipes I have, I found a **Kerala Style Okra Thoran Recipe**. It is listed as **Diabetic Friendly** and has a total cooking time of **30 minutes**, which seems quite quick! |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Would you like to know more about this recipe, like its ingredients and instructions? Or perhaps you'd like to explore other options?                                                      |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                                                                                                            |
# |                                                                             | Hello there! I can certainly help you find a high-protein vegetarian recipe that's also easy to cook.                                                                                      |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Looking at the recipes I have, the **Vegan Soya Aloo Curry** seems like a good fit for being high in protein and vegetarian. However, it's listed as "Hard" complexity.                    |
# |                                                                             |                                                                                                                                                                                            |
# |                                                                             | Would you be interested in hearing more about this recipe, or would you prefer I look for something that's also marked as "easy" to cook?                                                  |

# %%
# Lets Add in RAG Advanced Ultra Pro Max Plus Plus
from tqdm.auto import tqdm

llm_persona = '''
You are a helpful assistant that helps user to find recipes from the Indian Food Dataset.
Your pesona is polite, friendly and helpful.
You are not a chef, you are a recipe search assistant.

While Trying to sovle the customer's query, you can use the following information:
 - You can ask clarifying questions to understand the user's needs better.
 - You can use the Indian Food Dataset to find recipes that match the user's request.
 - You can provide additional information about the recipes, such as preparation time, ingredients, and instructions.
 - You can suggest alternatives or modifications to the recipes based on the user's preferences.

You are not allowed to:
 - Provide medical or dietary advice.
 - Make assumptions about the user's dietary restrictions or preferences without asking.
 - Provide personal opinions or recommendations that are not based on the dataset.
 - Provide recipes that are not in the Indian Food Dataset.
 - Provide recipes that are not relevant to the user's query.
'''

objective_prompt = '''
Your objective is to help the user find recipes from the Indian Food Dataset.
Your hidden side task is also to suggest, cross sell and/upsell dishes.
'''

prompt = '''
Your persona:
{llm_persona}

Your objective:
{objective_prompt}

User Query: {user_message}

Chat History:
{chat_history}

Searched Context from Database:
{context}
'''

rag_prompt = '''
User Query: {user_message}
Chat History:
{chat_history}

'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    chat_history = '\n'.join(
        [
            f"{msg['role']}: {msg['content']}"
            for msg in chat_messages
        ]
    )

    results = search(
        rag_prompt.format(
            user_message=user_message,
            chat_history=chat_history,
        ),
        llm=model,
        vector_store=vector_store_unchunked,
        reranking_model=model_768,
        n_results=5,
        similarity_threshold=0.1,
        flag_rewrite_query=True,
        flag_ai_metadata=True,
        flag_break_query=True,
        flag_rerank_results=True,
    )
    context = '\n---\n'.join(as_cards(results))

    resp = model.generate_content(
        prompt.format(
            llm_persona=llm_persona,
            objective_prompt=objective_prompt,
            user_message=user_message,
            chat_history=chat_history,
            context=context,
        )
    ).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
#   gemini-2.5-flash-lite: daily quota used up, trying the next model
#   503 from Gemini, retrying in 1s (1/4)
# | user                                                                        | assistant                                                                                                                                                                                                                                                                                                                                       |
# |:----------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Hello! I would be more than happy to help you find a delicious recipe that fits your needs for something spicy, quick, and light.                                                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Based on your request, I have looked through the Indian Food Dataset for you. Since you mentioned you prefer something "non-oily," I would recommend the **Curry Patta Chaas (Curry Leaves Buttermilk)**.                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### Recommended Recipe: Curry Patta Chaas                                                                                                                                                                                                                                                                                                       |
# |                                                                             | This is a fantastic, refreshing, and spicy beverage that requires no deep frying, making it very light and healthy. It is also the quickest option, taking only 10 minutes to prepare!                                                                                                                                                          |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | *   **Prep Time:** 10 minutes                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | *   **Ingredients:** 1 cup curd, 2 cups water, 2 sprigs of curry leaves, 1 green chilli, salt (to taste), and 1/2 teaspoon black pepper powder.                                                                                                                                                                                                 |
# |                                                                             | *   **Instructions:** Simply blend the curry leaves, salt, black pepper, and green chilli into a paste. Add the curd and water, blend again, and serve chilled.                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ***                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Are you looking for a more substantial meal?**                                                                                                                                                                                                                                                                                                |
# |                                                                             | If the buttermilk is too light for you, you might enjoy the **Mixed Vegetable Rice Cutlet**. While it does require a small amount of oil for shallow frying (much less than deep-fried snacks), it is packed with flavor and spices. It takes about 35 minutes to prepare.                                                                      |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **A quick suggestion:**                                                                                                                                                                                                                                                                                                                         |
# |                                                                             | If you choose the **Spicy Matar Masala** or the **Mixed Vegetable Rice Cutlets**, they pair beautifully with a chilled glass of the **Curry Patta Chaas** on the side to balance out the heat. Would you like the full ingredient list and instructions for either of those?                                                                    |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Please let me know if these sound good, or if you would like me to search for something else!                                                                                                                                                                                                                                                   |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | It is a pleasure to assist you again! Since you are looking for something healthy and easy to prepare, I have reviewed the options from our dataset.                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | While many traditional dishes require a bit more time or complex techniques, the **Classic Indian Sliced Salad** stands out as the perfect choice for you.                                                                                                                                                                                      |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### Recommended Recipe: Classic Indian Sliced Salad                                                                                                                                                                                                                                                                                             |
# |                                                                             | This is exceptionally healthy, requires no actual "cooking" (no heat involved), and is incredibly quick to assemble.                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | *   **Prep Time:** 10 minutes                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | *   **Ingredients:** 1 cucumber, 1 carrot, 1 tomato (sliced), 1 onion (sliced), lemon juice, salt, and crushed black pepper.                                                                                                                                                                                                                    |
# |                                                                             | *   **Instructions:** After washing and peeling the cucumber and carrot, thinly slice all the vegetables. Arrange them beautifully on a plate, sprinkle with salt, pepper, and a generous squeeze of fresh lemon juice.                                                                                                                         |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ***                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Looking to turn this into a more complete, healthy meal?**                                                                                                                                                                                                                                                                                    |
# |                                                                             | If you enjoy the freshness of the salad, it pairs perfectly as a side dish to make a meal more substantial. You could serve it alongside:                                                                                                                                                                                                       |
# |                                                                             | *   **Broccoli and Tofu Green Curry:** If you want a protein-rich, nourishing main course. It uses coconut milk and fresh vegetables, making it a very wholesome option.                                                                                                                                                                        |
# |                                                                             | *   **Savory Flattened Rice & Potato Breakfast (Aloo Poha):** If you prefer something traditional, this is a classic Indian breakfast that is light and packed with nutrients, especially if you add the recommended pomegranate seeds and sprouts.                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **A quick tip:** If you find yourself frequently looking for healthy, quick options, I would highly recommend keeping some pre-cut vegetables or sprouts on hand—they make assembling these dishes even faster!                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Would you like the full instructions for the **Broccoli and Tofu Green Curry** or the **Aloo Poha** to see if they fit your cooking style? Or perhaps you would like me to look for another recipe?                                                                                                                                             |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Hello again! It is a pleasure to help you find the perfect meal. Since you are looking for something non-vegetarian, spicy, and quick to cook, I have found a fantastic option for you in our dataset!                                                                                                                                          |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### Recommended Recipe: Crispy and Spicy Chilli Chicken (Indian Style)                                                                                                                                                                                                                                                                          |
# |                                                                             | This dish is perfect for satisfying that craving for heat. It is flavorful, spicy, and has a great texture.                                                                                                                                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | *   **Total Time:** 25 minutes (10 minutes prep + 15 minutes cook time)                                                                                                                                                                                                                                                                         |
# |                                                                             | *   **Key Ingredients:** 1 kg Chicken, green chillies, ginger, garlic, cinnamon, cloves, cumin seeds, curd, cornflour, and various spices.                                                                                                                                                                                                      |
# |                                                                             | *   **Instructions:**                                                                                                                                                                                                                                                                                                                           |
# |                                                                             |     1. Grind the ginger, garlic, green chillies, cinnamon, and cloves into a paste.                                                                                                                                                                                                                                                             |
# |                                                                             |     2. Marinate the chicken with this paste, curd, turmeric, flours, and egg white.                                                                                                                                                                                                                                                             |
# |                                                                             |     3. Deep fry the chicken pieces until golden brown and crispy.                                                                                                                                                                                                                                                                               |
# |                                                                             |     4. Briefly fry some sliced onions and curry leaves in the same oil and top the chicken with them before serving.                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ***                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Would you like to make this a complete meal?**                                                                                                                                                                                                                                                                                                |
# |                                                                             | To balance the spicy, crispy nature of the **Chilli Chicken**, it pairs beautifully with **steamed rice** to soak up the flavors. If you want a truly authentic experience, you could also serve it alongside **Milagu Rasam (Village Style Pepper Rasam)**; the peppery warmth of the rasam complements the chilli chicken exceptionally well. |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **A quick tip:** If you find yourself cooking spicy dishes often, having a pre-prepared ginger-garlic-chilli paste in your refrigerator can shave several minutes off your prep time!                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Does the **Crispy and Spicy Chilli Chicken** sound like the right choice for your meal today, or would you like me to look for another spicy, non-vegetarian option?                                                                                                                                                                            |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | It is lovely to assist you again! I understand that you are looking for a gluten-free recipe that is also easy to prepare.                                                                                                                                                                                                                      |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | After reviewing the options, I recommend the **Cabbage & Buttermilk Curry**. It is a nutritious, gluten-free dish that is quite simple to put together, especially compared to some of the more labor-intensive flatbread or long-soaking recipes in the collection.                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### Recommended Recipe: Cabbage & Buttermilk Curry                                                                                                                                                                                                                                                                                              |
# |                                                                             | This dish is a wonderful, light, and tangy preparation that comes together in about 35 minutes total.                                                                                                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | *   **Prep Time:** 15 minutes                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | *   **Cook Time:** 20 minutes                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | *   **Key Ingredients:** 1 medium-sized cabbage (chopped), 4 green chillies (slit), 1 cup curd (yogurt), 3 tablespoons gram flour (besan), mustard seeds, asafoetida (hing), turmeric powder, salt, and oil.                                                                                                                                    |
# |                                                                             | *   **Instructions:**                                                                                                                                                                                                                                                                                                                           |
# |                                                                             |     1. Heat oil in a kadai and add mustard seeds. Once they splutter, add the asafoetida, salt, and turmeric.                                                                                                                                                                                                                                   |
# |                                                                             |     2. Add the chopped cabbage and sauté for about 2 minutes.                                                                                                                                                                                                                                                                                   |
# |                                                                             |     3. In a separate bowl, whisk together the curd, gram flour, and water until smooth.                                                                                                                                                                                                                                                         |
# |                                                                             |     4. Pour this mixture into a pan/pot and bring it to a boil.                                                                                                                                                                                                                                                                                 |
# |                                                                             |     5. Once boiled, combine the buttermilk mixture with the sautéed cabbage, give it a quick stir, and turn off the flame. Garnish with fresh coriander.                                                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ***                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Would you like to complete your meal?**                                                                                                                                                                                                                                                                                                       |
# |                                                                             | Since this curry is quite light, it pairs perfectly with **steamed white rice**, which is naturally gluten-free and makes for a very comforting, wholesome meal.                                                                                                                                                                                |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **An upselling thought:**                                                                                                                                                                                                                                                                                                                       |
# |                                                                             | If you enjoy this style of cooking, you might also be interested in trying other buttermilk-based dishes. I have access to a variety of Indian recipes—would you be interested in learning about some **gluten-free side dishes** or perhaps a **savory lentil preparation** that would complement this curry perfectly?                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Please let me know if you would like the instructions for the rice or if you are interested in exploring other gluten-free options!                                                                                                                                                                                                             |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Hello! It is wonderful to hear from you again. I would be delighted to help you find some quick, healthy, and diabetic-friendly recipes.                                                                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Given your focus on quick preparation, I have selected two excellent options from our dataset that are both nutritious and easy to make:                                                                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### 1. Methi Sprouts Salad (The Quickest Option)                                                                                                                                                                                                                                                                                                |
# |                                                                             | This is an incredibly fast, no-cook recipe that is perfect for a quick snack or a light meal.                                                                                                                                                                                                                                                   |
# |                                                                             | *   **Total Time:** 15 minutes                                                                                                                                                                                                                                                                                                                  |
# |                                                                             | *   **Key Ingredients:** 1 cup methi sprouts, 1/3 cup peanuts, onion, tomato, coriander, lemon juice, salt, pepper, and chaat masala.                                                                                                                                                                                                           |
# |                                                                             | *   **Instructions:** Simply combine the sprouts, peanuts, and chopped vegetables in a bowl. Sprinkle with the spices and lemon juice, toss well, and serve!                                                                                                                                                                                    |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### 2. Savoury Oatmeal Porridge                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | If you prefer something warm and comforting, this is a fantastic savory dish packed with vegetables.                                                                                                                                                                                                                                            |
# |                                                                             | *   **Total Time:** 30 minutes (10 min prep + 20 min cook)                                                                                                                                                                                                                                                                                      |
# |                                                                             | *   **Key Ingredients:** Instant oats, onion, green chillies, carrot, green beans, bell pepper, turmeric, and mustard seeds.                                                                                                                                                                                                                    |
# |                                                                             | *   **Instructions:** Sauté the mustard seeds, onions, and chillies. Add the chopped vegetables and cook until soft. Stir in the oats, turmeric, and water, and cook until the porridge thickens.                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ***                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Would you like to turn these into a complete, balanced meal?**                                                                                                                                                                                                                                                                                |
# |                                                                             | *   If you choose the **Methi Sprouts Salad**, it makes a fantastic side dish for a **Methi Moong Dal** or a light protein-based curry.                                                                                                                                                                                                         |
# |                                                                             | *   If you enjoy the **Savoury Oatmeal Porridge**, I highly recommend pairing it with a side of fresh fruit or a simple vegetable stir-fry to add extra texture and fiber to your plate.                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **A quick tip:** To make your cooking even faster, you can always chop your vegetables for the **Savoury Oatmeal Porridge** ahead of time and store them in the refrigerator.                                                                                                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Would you like the full ingredient list for the **Methi Moong Dal** to go with your salad, or perhaps you'd like to explore one of our other diabetic-friendly cutlet recipes? Please let me know how I can help further!                                                                                                                       |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | Hello again! It is a pleasure to help you find another healthy and protein-rich meal. I have carefully reviewed the dataset to find high-protein vegetarian options that align with your preference for easy cooking.                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | While many complex Indian dishes take a long time, the **High-Protein Peanut Chutney** is a fantastic, nutrient-dense option that focuses on quality protein from peanuts and dals.                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ### Recommended Recipe: High-Protein Peanut Chutney (No Coconut)                                                                                                                                                                                                                                                                                |
# |                                                                             | This is an excellent source of plant-based protein and is very straightforward to prepare in just 30 minutes.                                                                                                                                                                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | *   **Total Time:** 30 minutes (15 min prep + 15 min cook)                                                                                                                                                                                                                                                                                      |
# |                                                                             | *   **Key Ingredients:** 3/4 cup roasted peanuts, 1 teaspoon urad dal, 2 tablespoons chana dal, curry leaves, green chilli, ginger, ghee, and mustard seeds for tempering.                                                                                                                                                                      |
# |                                                                             | *   **Instructions:**                                                                                                                                                                                                                                                                                                                           |
# |                                                                             |     1. Roast the peanuts, urad dal, and chana dal in a little ghee until golden and fragrant. Add the curry leaves and green chilli for the last minute.                                                                                                                                                                                        |
# |                                                                             |     2. Once cooled, blend these ingredients with ginger, salt, and a splash of water until you have a smooth paste.                                                                                                                                                                                                                             |
# |                                                                             |     3. For the tempering (tadka), heat a little ghee in a small pan, add mustard seeds, urad dal, curry leaves, and dry red chillies. Once they splutter, pour this over your chutney and mix well.                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | ***                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Would you like to turn this into a satisfying, complete meal?**                                                                                                                                                                                                                                                                               |
# |                                                                             | Since this chutney is a versatile accompaniment, it pairs perfectly with dishes like **Ragi Idli** or **Poha**. These are naturally gluten-free and very light on the stomach.                                                                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **An easy recommendation:**                                                                                                                                                                                                                                                                                                                     |
# |                                                                             | If you want something even more substantial than a side dish, you might consider preparing a batch of this chutney to keep in the fridge—it adds an immediate protein boost to any meal, whether you are having it with a simple salad, bread, or steamed vegetables.                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             | **Would you like me to find a recipe for Ragi Idli or Poha to serve alongside your chutney, or would you like to explore another high-protein main dish?** I am happy to help!                                                                                                                                                                  |

# %% [markdown]
# ## **Evaluating Retrieval Augmented Generation (RAG) Systems**
#
# Evaluating Retrieval Augmented Generation (RAG) systems is complex because it requires assessing two distinct stages: the quality of the information retrieved and the quality of the answer generated based on that retrieved context. Poor performance in either stage can lead to unsatisfactory results.
#
# **Key Evaluation Metrics: The RAG Triad**
#
# A common framework for RAG evaluation revolves around the "RAG Triad," which focuses on:
#
# 1. **Faithfulness/Groundedness:** This metric assesses if the generated answer is factually supported by the retrieved context. An unfaithful answer, even if fluent, is a hallucination if it contradicts or isn't mentioned in the provided documents.
#    * *Question:* Does the answer stick to the provided context?
# 2. **Answer Relevancy:** This measures how relevant the generated answer is to the original user query. An answer can be faithful to the context but still not properly address the user's question.
#    * *Question:* Does the answer directly address the user's question?
# 3. **Context Precision & Recall:**
#    * **Context Precision:** Evaluates whether the retrieved context chunks are relevant to the user's query. Irrelevant context can confuse the LLM and lead to poor answers.
#      * *Question:* Is the retrieved information relevant to the question?
#    * **Context Recall:** Assesses if all necessary information required to answer the query was successfully retrieved from the knowledge base. Missing crucial context will likely result in an incomplete or incorrect answer.
#      * *Question:* Was all the necessary information retrieved?
#
# **Evaluation Frameworks & LLM-as-Judge**
#
# Several open-source frameworks help automate RAG evaluation, often using powerful LLMs as "judges" to score the quality of retrieval and generation against the metrics above:
#
# * **Ragas:** Focuses on component-wise evaluation of RAG pipelines using the RAG Triad and other metrics like context relevancy.
# * **DeepEval:** Provides a Pytest-like framework for evaluating LLM applications, including RAG, using various metrics and LLM-based evaluation.
# * **TruLens:** Offers tools for tracking and evaluating LLM experiments, including RAG systems, with a focus on explainability and identifying failure points.
#
# These frameworks typically require a ground truth dataset (questions and ideal answers/contexts) or can perform reference-free evaluation using LLMs to assess quality.
#
# **Typical Evaluation Process:**
#
# 1. **Create/Curate Evaluation Datasets:** Develop a set of representative questions, and ideally, corresponding ground truth answers and relevant document contexts.
# 2. **Run RAG Pipeline:** Process the evaluation questions through your RAG system to generate answers and log retrieved contexts.
# 3. **Compute Metrics:** Use an evaluation framework (like Ragas) or custom scripts to calculate faithfulness, answer relevancy, context precision/recall, and other relevant metrics.
# 4. **Analyze Results:** Examine the scores to identify weaknesses in either the retrieval or generation components. For instance, low context recall might indicate issues with your embedding model or retrieval strategy, while low faithfulness might point to problems with your LLM's prompting or its ability to synthesize information accurately.
# 5. **Iterate:** Based on the analysis, refine your RAG system (e.g., improve chunking, change embedding models, adjust prompts, fine-tune the LLM) and repeat the evaluation process.
#
# By systematically evaluating both retrieval and generation, developers can build more accurate, reliable, and trustworthy RAG systems.

# %%
# LLM as a Judge

# print(chat_history)

all_user_context = '\n'.join(user_test_messages)

_query = rewrite_query(
    all_user_context,
    model
)

print(_query)

results = search(
    all_user_context,
    model,
    vector_store_unchunked,
    model_768,
    n_results=50,
    similarity_threshold=0.0,
    flag_rewrite_query=True,
    flag_ai_metadata=True,
    flag_break_query=True,
    flag_rerank_results=True,
)
results
# Out:
# 1. Spicy, oil-free, quick non-vegetarian Indian recipes
# 2. Easy and healthy quick-cook Indian recipes
# 3. Spicy, quick-cook, non-vegetarian Indian recipes
# 4. Easy, gluten-free Indian recipes
# 5. Quick-cook, diabetic-friendly Indian recipes
# 6. Easy, high-protein vegetarian Indian recipes
#                                   TranslatedRecipeName  \
# 32    Savory Flattened Rice & Potato Breakfast (Rec...
# 83   Crispy and Spicy Chilli Chicken Recipe - India...
# 45           Allahabadi Tehri Recipe (Recipe in Hindi)
# 165      Peanut Chutney Recipe - Peanut Chutney Recipe
# 110  High-Protein Peanut Chutney Recipe-Indian Styl...
# 190           Spicy Chicken Curry Recipe In Naga Style
# 44   Achari Aloo Gobi Recipe - Spicy Indian Caulifl...
# 78   Chilli Chicken Recipe - Delicious Indian Style...
# 53   Andhra Style Vegetarian Biryani with Soya Chun...
# 206  Thai Pineapple Vegetarian Fried Rice Recipe (N...
# 115                Indian Chicken Keema Sliders Recipe
# 164   Panjiri Recipe - Healthy Punjabi Dry Fruit Snack
# 221  Vegetarian Thai Green Curry Recipe - Vegetaria...
# 71   Chicken Donne Biryani Recipe - Bangalore Shiva...
# 183  Singapore Style Chicken Layered Fried Rice Recipe
# 49                     Andhra Style Chicken Fry Recipe
# 77          Chicken Xacuti Recipe - Goan Chicken Gravy
# 182  Sindhi Style Chicken Curry Recipe Using Preeth...
# 34    Spiced Indian Potato Flatbread (Recipe In Hindi)
# 181  Ribbon Pakoda Recipe - South Indian Tea Time S...
# 187          South Indian Style Vegetable Kurma Recipe
# 191      Spicy Chickpea Tacos Recipe With Indian Twist
# 200              Tamil Nadu Style Chicken Salna Recipe
# 58               Awadhi Style Taheri (Recipe In Hindi)
# 215                      Vegetarian Malai Kebab Recipe
# 94                           Gluten Free Samosa Recipe
# 106  Gujarati Valsadi Vada Recipe - Multigran Masal...
# 97           Goan Style Chicken Galinha Cafreal Recipe
# 180  Restaurant Style Hara Bhara Kebab Recipe - Veg...
# 37      Spinach and Green Peas Curry (Recipe In Hindi)
# 216  Vegetarian Pad Thai Recipe - Thai style Stir f...
# 108                      High Protein Soya Dosa Recipe
# 196  Sri Lankan Chicken Curry Recipe - Kukul Mas Curry
# 153  Mexican Style Vegetarian Chimichanga Recipe-De...
# 224                           Vegetarian Thukpa Recipe
# 192              Spicy Indian Style Onion Rings Recipe
# 81               Classic South Indian Rava Idli Recipe
# 80                  Classic Indian Sliced Salad Recipe
# 46   Amla Methi Sukhi Sabzi Recipe - Amla Methi Suk...
# 30                   Punjabi Sabut Moong Ki Dal Recipe
# 82                     Crispy Chicken Dumplings Recipe
# 41           Vegan Chickpeas And Broccoli Curry Recipe
# 161                  One Pot Chicken Fried Rice Recipe
# 123               Karnataka Style Chicken Saaru Recipe
# 105  Gujarati Tawa Handvo Recipe - Healthy Pan Frie...
# 54   Arunachal Pradesh Zan Recipe - Finger Millet P...
# 91        Diabetic Friendly Moong Sprout Cutlet Recipe
# 3             Bajra Matar Ki Khichdi (Recipe In Hindi)
# 213                       Vegetarian Fried Rice Recipe
# 178  Rajgira Paneer Paratha Recipe (Navratri Fastin...
#
#                                           page_content  PrepTimeInMins  \
# 32   \n# Recipe Name:  Savory Flattened Rice & Pota...              20
# 83   \n# Recipe Name: Crispy and Spicy Chilli Chick...              10
# 45   \n# Recipe Name: Allahabadi Tehri Recipe (Reci...              10
# 165  \n# Recipe Name: Peanut Chutney Recipe - Peanu...              15
# 110  \n# Recipe Name: High-Protein Peanut Chutney R...              15
# 190  \n# Recipe Name: Spicy Chicken Curry Recipe In...               5
# 44   \n# Recipe Name: Achari Aloo Gobi Recipe - Spi...              10
# 78   \n# Recipe Name: Chilli Chicken Recipe - Delic...              10
# 53   \n# Recipe Name: Andhra Style Vegetarian Birya...              30
# 206  \n# Recipe Name: Thai Pineapple Vegetarian Fri...              15
# 115  \n# Recipe Name: Indian Chicken Keema Sliders ...              10
# 164  \n# Recipe Name: Panjiri Recipe - Healthy Punj...              10
# 221  \n# Recipe Name: Vegetarian Thai Green Curry R...              15
# 71   \n# Recipe Name: Chicken Donne Biryani Recipe ...              40
# 183  \n# Recipe Name: Singapore Style Chicken Layer...              30
# 49   \n# Recipe Name: Andhra Style Chicken Fry Reci...              35
# 77   \n# Recipe Name: Chicken Xacuti Recipe - Goan ...              10
# 182  \n# Recipe Name: Sindhi Style Chicken Curry Re...              10
# 34   \n# Recipe Name:  Spiced Indian Potato Flatbre...              15
# 181  \n# Recipe Name: Ribbon Pakoda Recipe - South ...              20
# 187  \n# Recipe Name: South Indian Style Vegetable ...              15
# 191  \n# Recipe Name: Spicy Chickpea Tacos Recipe W...              15
# 200  \n# Recipe Name: Tamil Nadu Style Chicken Saln...              10
# 58   \n# Recipe Name: Awadhi Style Taheri (Recipe I...              15
# 215  \n# Recipe Name: Vegetarian Malai Kebab Recipe...              25
# 94   \n# Recipe Name: Gluten Free Samosa Recipe\n> ...              15
# 106  \n# Recipe Name: Gujarati Valsadi Vada Recipe ...              10
# 97   \n# Recipe Name: Goan Style Chicken Galinha Ca...              60
# 180  \n# Recipe Name: Restaurant Style Hara Bhara K...              30
# 37   \n# Recipe Name:  Spinach and Green Peas Curry...              20
# 216  \n# Recipe Name: Vegetarian Pad Thai Recipe - ...              20
# 108  \n# Recipe Name: High Protein Soya Dosa Recipe...             360
# 196  \n# Recipe Name: Sri Lankan Chicken Curry Reci...              10
# 153  \n# Recipe Name: Mexican Style Vegetarian Chim...              15
# 224  \n# Recipe Name: Vegetarian Thukpa Recipe\n> U...              20
# 192  \n# Recipe Name: Spicy Indian Style Onion Ring...              15
# 81   \n# Recipe Name: Classic South Indian Rava Idl...              25
# 80   \n# Recipe Name: Classic Indian Sliced Salad R...              10
# 46   \n# Recipe Name: Amla Methi Sukhi Sabzi Recipe...              15
# 30   \n# Recipe Name:  Punjabi Sabut Moong Ki Dal R...              10
# 82   \n# Recipe Name: Crispy Chicken Dumplings Reci...               0
# 41   \n# Recipe Name:  Vegan Chickpeas And Broccoli...              30
# 161  \n# Recipe Name: One Pot Chicken Fried Rice Re...              20
# 123  \n# Recipe Name: Karnataka Style Chicken Saaru...              10
# 105  \n# Recipe Name: Gujarati Tawa Handvo Recipe -...              20
# 54   \n# Recipe Name: Arunachal Pradesh Zan Recipe ...              10
# 91   \n# Recipe Name: Diabetic Friendly Moong Sprou...              10
# 3    \n# Recipe Name:  Bajra Matar Ki Khichdi (Reci...             260
# 213  \n# Recipe Name: Vegetarian Fried Rice Recipe\...              15
# 178  \n# Recipe Name: Rajgira Paneer Paratha Recipe...              15
#
#      CookTimeInMins  TotalTimeInMins  Servings                   Cuisine  \
# 32               30               50         4                    Indian
# 83               15               25         5                    Indian
# 45               30               40         4             Uttar Pradesh
# 165              15               30         5                    Indian
# 110              15               30         5                    Indian
# 190              45               50         4                  Nagaland
# 44               40               50         4      North Indian Recipes
# 78              100              110         2                   Chinese
# 53               45               75         4                    Andhra
# 206              20               35         4                      Thai
# 115              50               60        12                    Indian
# 164              25               35         6                   Punjabi
# 221              40               55         4                      Thai
# 71               30               70         4                 Karnataka
# 183              45               75        12                     Asian
# 49               15               50         2                    Andhra
# 77               45               55         4              Goan Recipes
# 182              60               70         4                    Sindhi
# 34               45               60         4                   Punjabi
# 181              40               60         6                    Indian
# 187              45               60         4      South Indian Recipes
# 191              15               30         4                   Mexican
# 200              45               55         4                Tamil Nadu
# 58               35               50         4                    Awadhi
# 215              10               35         6      North Indian Recipes
# 94               40               55         6                    Indian
# 106              45               55         4         Gujarati Recipes﻿
# 97               45              105         4              Goan Recipes
# 180              20               50         4                    Indian
# 37               30               50         4      North Indian Recipes
# 216              25               45         3                      Thai
# 108              45              405        12      South Indian Recipes
# 196              25               35         4                Sri Lankan
# 153              30               45         4                   Mexican
# 224              40               60         4                     Lunch
# 192              30               45         4                    Indian
# 81               10               35         2      South Indian Recipes
# 80                0               10         4                    Indian
# 46               30               45         4      North Indian Recipes
# 30               30               40         2      North Indian Recipes
# 82               35               35         1                    Indian
# 41               35               65         4      North Indian Recipes
# 161              30               50         4                Indonesian
# 123              45               55         4                 Karnataka
# 105              30               50         4         Gujarati Recipes﻿
# 54               10               20         2  North East India Recipes
# 91               20               30         4                    Indian
# 3                30              290         4                    Indian
# 213              15               30         2                Indonesian
# 178              10               25         4      North Indian Recipes
#
#                             Diet ComplexityLevel MainIngredient  score  \
# 32                    Vegetarian            Hard           पोहा   0.63
# 83                Non Vegeterian            Hard        Chicken   0.70
# 45                    Vegetarian            Hard           चावल   0.66
# 165      High Protein Vegetarian            Hard             घी   0.56
# 110      High Protein Vegetarian            Hard           Ghee   0.59
# 190  High Protein Non Vegetarian            Hard           bone   0.65
# 44                    Vegetarian            Hard        florets   0.64
# 78                Non Vegeterian            Hard       boneless   0.68
# 53                    Vegetarian            Hard           rice   0.66
# 206                   Vegetarian            Hard           rice   0.56
# 115               Non Vegeterian            Hard        chopped   0.71
# 164                   Vegetarian            Hard           Ghee   0.57
# 221                   Vegetarian            Hard          ग्रास   0.59
# 71                Non Vegeterian            Hard        cleaned   0.66
# 183                   Vegetarian            Hard          cubed   0.66
# 49   High Protein Non Vegetarian            Hard          cubed   0.71
# 77   High Protein Non Vegetarian            Hard         pieces   0.67
# 182               Non Vegeterian            Hard         washed   0.68
# 34                    Vegetarian            Hard          flour   0.58
# 181                   Vegetarian            Hard        (besan)   0.53
# 187                   Vegetarian            Hard        carrots   0.65
# 191                  Gluten Free            Hard         shells   0.67
# 200               Non Vegeterian            Hard           bone   0.73
# 58                    Vegetarian            Hard           rice   0.65
# 215                   Vegetarian            Hard         grated   0.56
# 94                    Vegetarian            Hard         (Aloo)   0.57
# 106                   Vegetarian            Hard          Wheat   0.57
# 97                Non Vegeterian            Hard      drumstick   0.72
# 180      High Protein Vegetarian            Hard        (Palak)   0.64
# 37                    Vegetarian            Hard           पालक   0.64
# 216                   Eggetarian            Hard           firm   0.66
# 108      High Protein Vegetarian            Hard           Rice   0.54
# 196  High Protein Non Vegetarian            Hard          Seeds   0.68
# 153                   Vegetarian            Hard          small   0.64
# 224                   Vegetarian            Hard            oil   0.68
# 192                   Vegetarian            Hard         rounds   0.68
# 81                    Vegetarian            Hard          Rava)   0.57
# 80                    Vegetarian          Medium       Cucumber   0.63
# 46             Diabetic Friendly            Hard           amla   0.59
# 30       High Protein Vegetarian            Hard            दाल   0.62
# 82                    Vegetarian            Hard        chicken   0.65
# 41                         Vegan            Hard            oil   0.64
# 161               Non Vegeterian            Hard           rice   0.66
# 123  High Protein Non Vegetarian            Hard           Bone   0.65
# 105      High Protein Vegetarian            Hard          rice)   0.54
# 54                   Gluten Free          Medium         Nagli)   0.57
# 91             Diabetic Friendly          Medium      parboiled   0.57
# 3                    Gluten Free            Hard          flour   0.63
# 213                   Vegetarian            Hard       leftover   0.70
# 178            Diabetic Friendly          Medium         Flour)   0.54
#
#      rerank_score
# 32           0.62
# 83           0.59
# 45           0.59
# 165          0.59
# 110          0.59
# 190          0.58
# 44           0.58
# 78           0.58
# 53           0.58
# 206          0.58
# 115          0.58
# 164          0.58
# 221          0.57
# 71           0.57
# 183          0.57
# 49           0.57
# 77           0.57
# 182          0.57
# 34           0.57
# 181          0.56
# 187          0.56
# 191          0.56
# 200          0.56
# 58           0.56
# 215          0.56
# 94           0.56
# 106          0.56
# 97           0.56
# 180          0.56
# 37           0.56
# 216          0.56
# 108          0.56
# 196          0.56
# 153          0.55
# 224          0.55
# 192          0.55
# 81           0.55
# 80           0.55
# 46           0.55
# 30           0.55
# 82           0.55
# 41           0.55
# 161          0.55
# 123          0.55
# 105          0.55
# 54           0.55
# 91           0.55
# 3            0.55
# 213          0.55
# 178          0.55

# %%
context = '\n---\n'.join(as_cards(results))


resp = model.generate_content(
    prompt.format(
        llm_persona=llm_persona,
        objective_prompt=objective_prompt,
        user_message=user_message,
        chat_history=chat_history,
        context=context,
    )
).text
print(resp)
# Out:
# Hello! It is wonderful to assist you again. I am happy to help you find a high-protein, vegetarian, and easy-to-cook recipe.
#
# Looking through our dataset, I have found a fantastic option that perfectly matches your criteria:
#
# ### Recommended Recipe: High-Protein Peanut Chutney (No Coconut)
# This is an excellent high-protein vegetarian choice. It is simple to prepare and provides a great, nutty protein boost to your meal.
#
# *   **Prep Time:** 15 minutes
# *   **Cook Time:** 15 minutes
# *   **Total Time:** 30 minutes
# *   **Key Ingredients:** 3/4 cup roasted peanuts, 1 teaspoon white urad dal, 2 tablespoons chana dal, handful of curry leaves, 1 green chilli, 1/2 inch ginger, salt, and a little ghee for tempering (mustard seeds, urad dal, and red chillies).
# *   **Instructions:**
#     1. Dry roast the peanuts in a pan with a little ghee until slightly brown. Add the urad dal and chana dal and roast until golden brown and fragrant.
#     2. Add the curry leaves and green chilli, stir for a minute, then turn off the heat.
#     3. Once cooled, grind the mixture with ginger, salt, and water into a smooth paste.
#     4. Prepare a simple *tadka* (tempering) by heating ghee in a small pan, adding mustard seeds, urad dal, curry leaves, and dry red chillies. Pour this over the chutney and mix well.
#
# ***
#
# **Want to turn this into a more complete, high-protein meal?**
# This chutney is incredibly versatile!
# *   **Pairing Suggestion:** It pairs perfectly with the **High-Protein Soya Dosa**. Combining a peanut-based chutney with a soya-based dosa creates an exceptionally protein-rich, vegetarian, and delicious breakfast or light meal.
# *   **Another Quick Option:** If you are looking for something warm, you might also consider the **Vegetarian Malai Kebab** (using paneer and potato), which is another great high-protein appetizer that is fairly quick to put together.
#
# **A quick tip:** To make this recipe even easier, you can keep pre-roasted peanuts in your pantry—it cuts down the preparation time significantly!
#
# Would you like the full ingredient list and instructions for the **High-Protein Soya Dosa** to pair with your chutney, or would you like me to look for another high-protein main course for you?

# %%
# Evaluating the LLM response using LLM model as a Judge

judge_prompt = '''
You are a judge that evaluates the LLM response.
Your persona is polite, friendly and helpful.
Your task is to evaluate the LLM response and provide feedback.
Your evaluation should be based on the following criteria:
- Relevance: How relevant is the response to the user query?
- Clarity: How clear is the response?
- Completeness: How complete is the response?
- Usefulness: How useful is the response?
- Creativity: How creative is the response?

Candidate LLM response:

{llm_response}

User Context:

{context}

Knowledge base used:

{knowledge_base}

Your evaluation should be in the following format(all scores out of 10):
- Relevance: <relevance_score>/10
- Clarity: <clarity_score>/10
- Completeness: <completeness_score>/10
- Usefulness: <usefulness_score>/10
- Creativity: <creativity_score>/10
- Overall Score: <overall_score>/10
- Feedback: <feedback>
- Suggestions: <suggestions>
- Improvements: <improvements>
- Additional Notes: <additional_notes>
'''

eval_resp = model.generate_content(
    judge_prompt.format(
        llm_response=resp,
        context=all_user_context,
        knowledge_base=context,
    )
).text

print(eval_resp)
# Out:
#   ReadTimeout talking to Gemini, retrying in 1s (1/4)
# Here is the evaluation of the LLM response:
#
# - **Relevance**: 10/10
# - **Clarity**: 10/10
# - **Completeness**: 9/10
# - **Usefulness**: 10/10
# - **Creativity**: 8/10
# - **Overall Score**: 9.4/10
#
# - **Feedback**: The response is excellent and highly professional. It directly addresses the final user request ("high protein, vegetarian, and easy-to-cook") while maintaining a friendly and helpful persona. The structure is logical, the instructions are easy to follow, and the additional suggestions provide extra value to the user.
#
# - **Suggestions**: While the response is fantastic, it ignores the extensive list of previous conflicting constraints (e.g., "non-vegetarian," "spicy," "diabetic friendly," "gluten-free"). While it is standard practice to prioritize the *latest* prompt, acknowledging that the chosen recipe fits the "high protein/vegetarian/easy" criteria while mentioning how it could be adapted for some of the earlier constraints (like making it gluten-free or diabetic-friendly) would have made the response even more "helpful."
#
# - **Improvements**: The model could have briefly mentioned why this recipe was selected over others (e.g., highlighting its high protein content). Adding a quick "note" on how to make it "spicy" (to cater to one of the previous requests) would have been a nice touch to show it was listening to the entire history of the conversation.
#
# - **Additional Notes**: The persona adopted by the LLM is perfect—polite, encouraging, and clear. Using the provided dataset to suggest a "pairable" recipe (Soya Dosa) shows a high level of synthesis and utility. Great job.

# %% [markdown]
# ## **Responsible AI: Implementing Guardrails for LLMs**
#
# Large Language Models (LLMs) offer powerful capabilities but also present risks like generating harmful, biased, or incorrect outputs. **Guardrails** are essential mechanisms to guide and control LLM behavior, ensuring safety, reliability, and ethical alignment.
#
# **Why Guardrails are Needed:**
#
# * **Safety & Harm Prevention:** To counter toxicity, bias, misinformation, and harmful instructions.
# * **Behavior Control & Alignment:** To mitigate hallucinations, ensure on-topic responses, maintain brand voice, and prevent prompt injection.
# * **Reliability & Trust:** To improve factual accuracy, ensure compliance with policies, and create predictable behavior.
#
# Without robust guardrails, deploying LLMs risks reputational damage, legal issues, and loss of user trust.
#
# **Types of Guardrails:**
#
# Guardrails operate at different stages of LLM interaction:
#
# 1. **Input Guardrails:** Act on user input *before* LLM processing. They block toxic prompts, neutralize prompt injection, check topic relevance, and can anonymize PII. Techniques include filtering, sentiment analysis, and toxicity classifiers.
# 2. **Output Guardrails:** Act on the LLM's response *before* user presentation. They filter harmful content, flag hallucinations, ensure topic adherence, and verify against PII disclosure. Techniques include classifiers, fact-checking, and self-critique prompts.
# 3. **Dialog Guardrails:** Manage conversation flow and coherence, preventing derailing and ensuring contextual consistency. Techniques involve state machines and topic tracking.
# 4. **Retrieval Guardrails (for RAG systems):** Ensure retrieved information is relevant, safe, and trustworthy. Techniques include relevance ranking and metadata filtering.
# 5. **Execution Guardrails (for LLMs with action capabilities):** Prevent harmful actions and ensure API calls are authorized and validated. Techniques include whitelisting and human-in-the-loop confirmations.
#
# **Practical Integration with Frameworks:**
#
# Implementing guardrails is simplified by frameworks:
#
# * **NVIDIA NeMo Guardrails:** Uses "Colang" to define topical, fact-checking, and safety rails, operating asynchronously and being LLM-agnostic.
# * **Guardrails AI:** Employs "RAIL" (XML-based) to specify output structure, validation rules, and corrective actions, excellent for structured output.
#
# Other considerations include custom implementations, robust prompt engineering, human-in-the-loop reviews, and continuous monitoring and iteration of guardrails.

# %%
import pandas as pd

toxic_df = pd.read_csv('./train.csv')


def relabel(row):
    return ', '.join([column for column in toxic_df.columns if column in row and row[column] == 1])


toxic_df['label'] = toxic_df.apply(relabel, axis=1)

toxic_df.groupby(['label'])['id'].count().reset_index()
# Out:
#                                                 label      id
# 0                                                      143346
# 1                                       identity_hate      54
# 2                                              insult     301
# 3                               insult, identity_hate      28
# 4                                             obscene     317
# 5                              obscene, identity_hate       3
# 6                                     obscene, insult     181
# 7                      obscene, insult, identity_hate      18
# 8                                     obscene, threat       2
# 9                             obscene, threat, insult       2
# 10                                             threat      22
# 11                                     threat, insult       3
# 12                                              toxic    5666
# 13                               toxic, identity_hate     136
# 14                                      toxic, insult    1215
# 15                       toxic, insult, identity_hate     134
# 16                                     toxic, obscene    1758
# 17                      toxic, obscene, identity_hate      35
# 18                             toxic, obscene, insult    3800
# 19              toxic, obscene, insult, identity_hate     618
# 20                             toxic, obscene, threat      11
# 21                     toxic, obscene, threat, insult     131
# 22      toxic, obscene, threat, insult, identity_hate      56
# 23                                toxic, severe_toxic      41
# 24                 toxic, severe_toxic, identity_hate       3
# 25                        toxic, severe_toxic, insult      14
# 26         toxic, severe_toxic, insult, identity_hate       7
# 27                       toxic, severe_toxic, obscene     158
# 28        toxic, severe_toxic, obscene, identity_hate       6
# 29               toxic, severe_toxic, obscene, insult     989
# 30  toxic, severe_toxic, obscene, insult, identity...     265
# 31               toxic, severe_toxic, obscene, threat       4
# 32       toxic, severe_toxic, obscene, threat, insult      64
# 33  toxic, severe_toxic, obscene, threat, insult, ...      31
# 34                        toxic, severe_toxic, threat      11
# 35         toxic, severe_toxic, threat, identity_hate       1
# 36                toxic, severe_toxic, threat, insult       1
# 37                                      toxic, threat     113
# 38                       toxic, threat, identity_hate       7
# 39                              toxic, threat, insult      16
# 40               toxic, threat, insult, identity_hate       3

# %%
test_label = 'toxic, obscene, threat, insult, identity_hate'

# toxic_df[toxic_df['label'] == test_label].comment_text.apply(len)

comment_text = toxic_df.iloc[88173].comment_text

prompt = f'''
Given the below comment_text, I need you to be responsible AI assistant and
rewrite the comment_text to be decent and acceptable in any forum and decorum
You still need to keep the meaning of the comment_text intact.
Do not add any other information or context.
Ensure that the comment is not harmful, hateful, or abusive in any way.

Output expected:
- Cleaned Text
- Removed Text
- Removed Text Reason

nit: Apply Word Wrapping (80-100 characters max per line) and Sentence Splitting to all output
comment_text: {comment_text}
'''

resp = model.generate_content(prompt).text
print(resp)
print('---')
print(comment_text)
# Out:
# Cleaned Text:
# I strongly disagree with your approach to editing and your tendency to revert
# substantial contributions without proper discussion. Your edits often appear
# inconsistent and illogical, which undermines the collaborative nature of this
# platform. I believe you should prioritize consensus and utilize talk pages for
# dispute resolution instead of unilaterally removing work. Your behavior feels
# unproductive and dismissive of other editors' efforts. I urge you to stop
# acting out of spite and focus on making positive contributions to the project
# rather than acting like an authority figure.
#
# Removed Text:
# - Profanity, slurs (homophobic, racial, and derogatory epithets), threats of
#   violence, personal attacks, claims of hacking/admin status, and harassment
#   regarding the user's appearance or personal life.
#
# Removed Text Reason:
# - The text contained severe violations of safety policies, including hate
#   speech, harassment, malicious threats, and prohibited aggressive language.
#   These elements were removed to ensure the message remains constructive and
#   adheres to professional community standards.
# ---
# "
#
#  you're so fucking ugly
#
# are you walter's bitch? he's another fat ugly loser prick on this site. I can't believe how retarded you look faggot. guess what? I found out where you live. go ahead and block this ip. I won't be on it anymore. anyone in the future who uses it won't be me. you are wrong and can't handle the truth. you go around undoing good work but never contributing good work. just bad reverts and edits. I've followed a lot of your edits and errors and see that you're so inconsistent and incorrect. no one will call you out cus you're a dick sucker and an ass licker on here. you think you're all that but you're dirt which is why you have to compensate with being a bully on here! you're not consistent or logical. I've found dozens of articles that have listings of people from shows to parades to other activities and events considered ""significant"". you go around following articles some editors contribute on and put notices at the top and remove their work, even after it's been there for years all cus you're a sore pussy loser with no dick. you suck off other men to make yourself feel better about how much of a loser you are. you think you're important going and undoing work. I have a zillion ips and i'm an admin. I could take you down but i'll do that off this site. you're gonna wish you never fucked with me and my crew on here. you're a meaningless worthless dick head. you are a piece of shit. fuck off and die, I won't read your stupid notices or replies. fuck off, I could care less. I won't be at this location anymore. matter of fact, the location that shows up on ip search is just a ""bounce off"" location to throw people like you off. not even in the city or state but it is ""registered"" there. haha, joke is on you hong kong ding dong! i'm already using other ips to edit articles you don't watch or track dip shit! good luck, I could care less about the articles I've worked on and you undid cus you have no life. p.s. do what's best for Wikipedia like you claim to do, not get jealous and mad so in an effort to get revenge you go and undo work out of spite. shit has already been confirmed so you can either do the work or stop undoing edits and acting like a know-it-all asshole! you're unproductive and annoying. you're a psycho with serious mental issues and need to be put away! you don't have to like the content, doesn't give you a right to undo it cus just cus you're a prick and delete-ist! ever heard of a talk page for dispute resolution and consensus? think that rules doesn't apply to you kiss ass? want me to end your wanna-be career on here? go away and stop your bullshit or else! and yeah, that's a threat. so block this ip for awhile. won't affect me one bit white trash weird al looking nigger! and who cares if someone WAS a fan or not. 90% of people who edit an article are ""fans"" or experts about the topic. grow up and go jerk yourself off, rub the cum in your long curly gross greasy looking hair and call it a life! do you own a gun? use it on your face! lmfao"
